# %%
#!/usr/bin/env python3

import os
import re

SOURCE_DIR = 'misc_trees'
DEST_DIR = 'misc_trees_labeled'

os.makedirs(DEST_DIR, exist_ok=True)

# Prefixes that should be labeled as {Foreground}
foreground_prefixes = ['mm', 'ml', 'md', 'mb', 'dr', 'rf']

# Regex: capture (1) node/tip name, (2) colon+branch_length
pattern = re.compile(r'([^\(\),:]+)(:[0-9\.eE\-\+]+)')

def replacer(match):
    """Decide {Foreground} vs. {Background}."""
    taxon_name = match.group(1)
    branch_length = match.group(2)
    if any(taxon_name.startswith(pref) for pref in foreground_prefixes):
        return f"{taxon_name}{{Foreground}}{branch_length}"
    else:
        return f"{taxon_name}{{Background}}{branch_length}"

for filename in os.listdir(SOURCE_DIR):
    if filename.endswith('.nwk'):
        source_file = os.path.join(SOURCE_DIR, filename)
        dest_file = os.path.join(DEST_DIR, filename)

        with open(source_file, 'r') as infile:
            data = infile.read()

        # --- FORCE ONE LINE ---
        # Remove all linebreaks:
        data = data.replace('\n', '').replace('\r', '')
        # (Optional) remove extra spaces if you like:
        # data = ' '.join(data.split())

        # Perform the labeling
        data_labeled = pattern.sub(replacer, data)

        # Write out WITHOUT adding an extra newline at the end
        with open(dest_file, 'w') as outfile:
            outfile.write(data_labeled)

        print(f"Processed {filename} -> {dest_file}")
# Out:
# Processed NP_054706.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\NP_054706.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed O14793.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\O14793.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed O15217.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\O15217.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed O43684.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\O43684.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed O75355.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\O75355.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed O75907.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\O75907.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed O95405_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\O95405_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P04626.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P04626.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P04732.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P04732.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P04818.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P04818.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P08138_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P08138_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P0DMV8.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P0DMV8.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P0DMV9.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P0DMV9.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P11362.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P11362.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P22001.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P22001.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P23458.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P23458.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P28799.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P28799.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P31645.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P31645.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P32245.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P32245.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P60983.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P60983.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P62136_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P62136_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed P68104_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\P68104_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q01081_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q01081_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q03468_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q03468_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q07960.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q07960.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q09328.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q09328.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q12849_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q12849_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q12929.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q12929.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q13148.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q13148.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q13574_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q13574_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q14103.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q14103.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q86X52.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q86X52.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q8N726.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q8N726.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q96DY7.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q96DY7.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q9BPW8_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q9BPW8_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q9BUF5_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q9BUF5_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q9BZW2.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q9BZW2.1_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q9GZV4.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q9GZV4.3_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q9H0Z9.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q9H0Z9.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
# Processed Q9H3U7.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk -> misc_trees_labeled\Q9H3U7.2_nucleotide.fasta_aligned_codon_alignment.fasta_pruned.nwk
