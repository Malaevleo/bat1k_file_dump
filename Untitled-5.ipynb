# %%
# %pip install bioemu
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: bioemu in c:\anaconda\lib\site-packages (0.1.4)
# Requirement already satisfied: mdtraj>=1.9.9 in c:\anaconda\lib\site-packages (from bioemu) (1.10.3)
# Requirement already satisfied: torch_geometric==2.6.1 in c:\anaconda\lib\site-packages (from bioemu) (2.6.1)
# Collecting torch==2.4.0 (from bioemu)
#   Using cached torch-2.4.0-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Requirement already satisfied: torchvision in c:\anaconda\lib\site-packages (from bioemu) (0.19.0)
# Requirement already satisfied: modelcif==0.7 in c:\anaconda\lib\site-packages (from bioemu) (0.7)
# Requirement already satisfied: bio>=1.5.9 in c:\anaconda\lib\site-packages (from bioemu) (1.7.1)
# Requirement already satisfied: fire==0.7.0 in c:\anaconda\lib\site-packages (from bioemu) (0.7.0)
# Requirement already satisfied: huggingface-hub in c:\anaconda\lib\site-packages (from bioemu) (0.29.2)
# Requirement already satisfied: hydra-core in c:\anaconda\lib\site-packages (from bioemu) (1.3.2)
# Requirement already satisfied: dm-tree in c:\anaconda\lib\site-packages (from bioemu) (0.1.9)
# Requirement already satisfied: stackprinter in c:\anaconda\lib\site-packages (from bioemu) (0.2.12)
# Requirement already satisfied: typer in c:\anaconda\lib\site-packages (from bioemu) (0.15.2)
# Requirement already satisfied: termcolor in c:\anaconda\lib\site-packages (from fire==0.7.0->bioemu) (2.5.0)
# Requirement already satisfied: ihm>=0.34 in c:\anaconda\lib\site-packages (from modelcif==0.7->bioemu) (2.2)
# Requirement already satisfied: filelock in c:\anaconda\lib\site-packages (from torch==2.4.0->bioemu) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\anaconda\lib\site-packages (from torch==2.4.0->bioemu) (4.12.2)
# Requirement already satisfied: sympy in c:\anaconda\lib\site-packages (from torch==2.4.0->bioemu) (1.13.3)
# Requirement already satisfied: networkx in c:\anaconda\lib\site-packages (from torch==2.4.0->bioemu) (3.3)
# Requirement already satisfied: jinja2 in c:\anaconda\lib\site-packages (from torch==2.4.0->bioemu) (3.1.4)
# Requirement already satisfied: fsspec in c:\anaconda\lib\site-packages (from torch==2.4.0->bioemu) (2024.3.1)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from torch==2.4.0->bioemu) (75.6.0)
# Requirement already satisfied: aiohttp in c:\anaconda\lib\site-packages (from torch_geometric==2.6.1->bioemu) (3.9.5)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from torch_geometric==2.6.1->bioemu) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in c:\anaconda\lib\site-packages (from torch_geometric==2.6.1->bioemu) (5.9.0)
# Requirement already satisfied: pyparsing in c:\anaconda\lib\site-packages (from torch_geometric==2.6.1->bioemu) (3.2.0)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from torch_geometric==2.6.1->bioemu) (2.32.2)
# Requirement already satisfied: tqdm in c:\anaconda\lib\site-packages (from torch_geometric==2.6.1->bioemu) (4.66.4)
# Requirement already satisfied: biopython>=1.80 in c:\anaconda\lib\site-packages (from bio>=1.5.9->bioemu) (1.84)
# Requirement already satisfied: gprofiler-official in c:\anaconda\lib\site-packages (from bio>=1.5.9->bioemu) (1.0.0)
# Requirement already satisfied: mygene in c:\anaconda\lib\site-packages (from bio>=1.5.9->bioemu) (3.2.2)
# Requirement already satisfied: pandas in c:\anaconda\lib\site-packages (from bio>=1.5.9->bioemu) (2.2.2)
# Requirement already satisfied: pooch in c:\anaconda\lib\site-packages (from bio>=1.5.9->bioemu) (1.8.2)
# Requirement already satisfied: scipy in c:\anaconda\lib\site-packages (from mdtraj>=1.9.9->bioemu) (1.14.1)
# Requirement already satisfied: packaging in c:\anaconda\lib\site-packages (from mdtraj>=1.9.9->bioemu) (23.2)
# Requirement already satisfied: netCDF4 in c:\anaconda\lib\site-packages (from mdtraj>=1.9.9->bioemu) (1.7.2)
# Requirement already satisfied: absl-py>=0.6.1 in c:\anaconda\lib\site-packages (from dm-tree->bioemu) (2.1.0)
# Requirement already satisfied: attrs>=18.2.0 in c:\anaconda\lib\site-packages (from dm-tree->bioemu) (23.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in c:\anaconda\lib\site-packages (from dm-tree->bioemu) (1.17.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda\lib\site-packages (from huggingface-hub->bioemu) (6.0.1)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\anaconda\lib\site-packages (from hydra-core->bioemu) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\anaconda\lib\site-packages (from hydra-core->bioemu) (4.9.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\anaconda\lib\site-packages (from torchvision->bioemu) (10.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\anaconda\lib\site-packages (from typer->bioemu) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\anaconda\lib\site-packages (from typer->bioemu) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\anaconda\lib\site-packages (from typer->bioemu) (13.9.4)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from click>=8.0.0->typer->bioemu) (0.4.6)
# Requirement already satisfied: msgpack in c:\anaconda\lib\site-packages (from ihm>=0.34->modelcif==0.7->bioemu) (1.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda\lib\site-packages (from rich>=10.11.0->typer->bioemu) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda\lib\site-packages (from rich>=10.11.0->typer->bioemu) (2.15.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\anaconda\lib\site-packages (from aiohttp->torch_geometric==2.6.1->bioemu) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\anaconda\lib\site-packages (from aiohttp->torch_geometric==2.6.1->bioemu) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\anaconda\lib\site-packages (from aiohttp->torch_geometric==2.6.1->bioemu) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\anaconda\lib\site-packages (from aiohttp->torch_geometric==2.6.1->bioemu) (1.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\lib\site-packages (from jinja2->torch==2.4.0->bioemu) (2.1.3)
# Requirement already satisfied: biothings-client>=0.2.6 in c:\anaconda\lib\site-packages (from mygene->bio>=1.5.9->bioemu) (0.4.1)
# Requirement already satisfied: cftime in c:\anaconda\lib\site-packages (from netCDF4->mdtraj>=1.9.9->bioemu) (1.6.4.post1)
# Requirement already satisfied: certifi in c:\anaconda\lib\site-packages (from netCDF4->mdtraj>=1.9.9->bioemu) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\lib\site-packages (from pandas->bio>=1.5.9->bioemu) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas->bio>=1.5.9->bioemu) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\lib\site-packages (from pandas->bio>=1.5.9->bioemu) (2023.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\anaconda\lib\site-packages (from pooch->bio>=1.5.9->bioemu) (3.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->torch_geometric==2.6.1->bioemu) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->torch_geometric==2.6.1->bioemu) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->torch_geometric==2.6.1->bioemu) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\lib\site-packages (from sympy->torch==2.4.0->bioemu) (1.3.0)
# Requirement already satisfied: httpx>=0.22.0 in c:\anaconda\lib\site-packages (from biothings-client>=0.2.6->mygene->bio>=1.5.9->bioemu) (0.27.0)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->bioemu) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas->bio>=1.5.9->bioemu) (1.16.0)
# Requirement already satisfied: anyio in c:\anaconda\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->bio>=1.5.9->bioemu) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\anaconda\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->bio>=1.5.9->bioemu) (1.0.2)
# Requirement already satisfied: sniffio in c:\anaconda\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->bio>=1.5.9->bioemu) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene->bio>=1.5.9->bioemu) (0.14.0)
# Using cached torch-2.4.0-cp312-cp312-win_amd64.whl (197.8 MB)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1
#     Uninstalling torch-2.4.1:
#       Successfully uninstalled torch-2.4.1
# Successfully installed torch-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.4.1+cu124 requires torch==2.4.1+cu124, but you have torch 2.4.0 which is incompatible.

# %%
# %pip install colabfold
# Out:
# Requirement already satisfied: colabfold in c:\anaconda\lib\site-packages (1.5.4)
# Requirement already satisfied: absl-py<2.0.0,>=1.0.0 in c:\anaconda\lib\site-packages (from colabfold) (1.4.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in c:\anaconda\lib\site-packages (from colabfold) (1.4.4)
# Requirement already satisfied: biopython<=1.82 in c:\anaconda\lib\site-packages (from colabfold) (1.82)
# Requirement already satisfied: dm-haiku<0.0.12,>=0.0.11 in c:\anaconda\lib\site-packages (from colabfold) (0.0.11)
# Requirement already satisfied: importlib-metadata<5.0.0,>=4.8.2 in c:\anaconda\lib\site-packages (from colabfold) (4.13.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.2.2 in c:\anaconda\lib\site-packages (from colabfold) (3.9.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.6 in c:\anaconda\lib\site-packages (from colabfold) (1.26.4)
# Requirement already satisfied: pandas<2.0.0,>=1.3.4 in c:\anaconda\lib\site-packages (from colabfold) (1.5.3)
# Requirement already satisfied: py3Dmol<3.0.0,>=2.0.1 in c:\anaconda\lib\site-packages (from colabfold) (2.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.26.0 in c:\anaconda\lib\site-packages (from colabfold) (2.32.2)
# Requirement already satisfied: tensorflow-cpu<3.0.0,>=2.12.1 in c:\anaconda\lib\site-packages (from colabfold) (2.18.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.62.2 in c:\anaconda\lib\site-packages (from colabfold) (4.66.4)
# Requirement already satisfied: jmp>=0.0.2 in c:\anaconda\lib\site-packages (from dm-haiku<0.0.12,>=0.0.11->colabfold) (0.0.4)
# Requirement already satisfied: tabulate>=0.8.9 in c:\anaconda\lib\site-packages (from dm-haiku<0.0.12,>=0.0.11->colabfold) (0.9.0)
# Requirement already satisfied: flax>=0.7.1 in c:\anaconda\lib\site-packages (from dm-haiku<0.0.12,>=0.0.11->colabfold) (0.10.4)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda\lib\site-packages (from importlib-metadata<5.0.0,>=4.8.2->colabfold) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->colabfold) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->colabfold) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->colabfold) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->colabfold) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->colabfold) (23.2)
# Requirement already satisfied: pillow>=8 in c:\anaconda\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->colabfold) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->colabfold) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib<4.0.0,>=3.2.2->colabfold) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas<2.0.0,>=1.3.4->colabfold) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.26.0->colabfold) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.26.0->colabfold) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.26.0->colabfold) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests<3.0.0,>=2.26.0->colabfold) (2024.8.30)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\anaconda\lib\site-packages (from tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (5.29.3)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (75.6.0)
# Requirement already satisfied: six>=1.12.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (3.9.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\anaconda\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (0.4.1)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from tqdm<5.0.0,>=4.62.2->colabfold) (0.4.6)
# Requirement already satisfied: jax>=0.4.27 in c:\anaconda\lib\site-packages (from flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.5.2)
# Requirement already satisfied: msgpack in c:\anaconda\lib\site-packages (from flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (1.0.3)
# Requirement already satisfied: optax in c:\anaconda\lib\site-packages (from flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in c:\anaconda\lib\site-packages (from flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.11.8)
# Requirement already satisfied: tensorstore in c:\anaconda\lib\site-packages (from flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.1.72)
# Requirement already satisfied: rich>=11.1 in c:\anaconda\lib\site-packages (from flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\anaconda\lib\site-packages (from flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (6.0.1)
# Requirement already satisfied: treescope>=0.1.7 in c:\anaconda\lib\site-packages (from flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.1.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (0.43.0)
# Requirement already satisfied: jaxlib<=0.5.2,>=0.5.1 in c:\anaconda\lib\site-packages (from jax>=0.4.27->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.5.1)
# Requirement already satisfied: scipy>=1.11.1 in c:\anaconda\lib\site-packages (from jax>=0.4.27->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (1.14.1)
# Requirement already satisfied: namex in c:\anaconda\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (0.0.8)
# Requirement already satisfied: optree in c:\anaconda\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (0.14.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda\lib\site-packages (from rich>=11.1->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda\lib\site-packages (from rich>=11.1->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (2.15.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\anaconda\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in c:\anaconda\lib\site-packages (from optax->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.1.89)
# Requirement already satisfied: etils[epy] in c:\anaconda\lib\site-packages (from optax->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (1.12.1)
# Requirement already satisfied: nest_asyncio in c:\anaconda\lib\site-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (1.6.0)
# Requirement already satisfied: humanize in c:\anaconda\lib\site-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (4.12.1)
# Requirement already satisfied: simplejson>=3.16.0 in c:\anaconda\lib\site-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (3.20.1)
# Requirement already satisfied: toolz>=0.9.0 in c:\anaconda\lib\site-packages (from chex>=0.1.87->optax->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.12.0)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow-cpu<3.0.0,>=2.12.1->colabfold) (2.1.3)
# Requirement already satisfied: fsspec in c:\anaconda\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (2024.3.1)
# Requirement already satisfied: importlib_resources in c:\anaconda\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.1->dm-haiku<0.0.12,>=0.0.11->colabfold) (6.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bioemu.sample import main as sample
sample(sequence='GYDPETGTWG', num_samples=10, output_dir='~/test_chignolin')
# Out:
# File "c:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     3541  async def run_code(self, code_obj, result=None, *, async_=False):
#  (...)
#     3573          try:
#     3574              if async_:
#     3575                  await eval(code_obj, self.user_global_ns, self.user_ns)
#     3576              else:
# --> 3577                  exec(code_obj, self.user_global_ns, self.user_ns)
#     3578          finally:
#     ..................................................
#      self = <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000016C
#              39E929C0>
#      code_obj = <code object <module> at 0x0000016C5F563750, file "C:\Users\
#                  Леонид\AppData\Local\Temp\ipykernel_4576\2298233248.py", lin
#                  e 1>
#      result = <ExecutionResult object at 16c5f5956a0, execution_count=8 er
#                ror_before_exec=None error_in_exec=Something went wrong duri
#                ng colabfold install: /bin/bash: C:AnacondaLibsite-packagesb
#                ioemucolabfold_setupsetup.sh: No such file or directory
#                info=<ExecutionInfo object at 16c5f5956d0, raw_cell="from b
#                ioemu.sample import main as sample
#               sample(se.." store_history=True silent=False shell_futures=T
#                rue cell_id=vscode-notebook-cell:Untitled-5.ipynb?jupyter-no
#                tebook#W2sdW50aXRsZWQ%3D> result=None>
#      async_ = False
#      self.user_global_ns = {'__name__': '__main__',
#                             '__doc__': 'Automatically created module for IPython intera
#                             ctive environment',
#                             '__package__': None,
#                             '__loader__': None,
#                             '__spec__': None,
#                             '__builtin__': <module 'builtins' (built-in)>,
#                             '__builtins__': <module 'builtins' (built-in)>,
#                             '_ih': ['', "get_ipython().run_line_magic('pip', 'install b
#                             ioemu')", "get_ipython().run_line_magic('pip', 'install torc
#                             h==2.4.1')", "get_ipython().run_line_magic('pip', 'install b
#                             ioemu')", "from bioemu.sample import main as sample\nsam...
#      self.user_ns = {'__name__': '__main__',
#                      '__doc__': 'Automatically created module for IPython intera
#                      ctive environment',
#                      '__package__': None,
#                      '__loader__': None,
#                      '__spec__': None,
#                      '__builtin__': <module 'builtins' (built-in)>,
#                      '__builtins__': <module 'builtins' (built-in)>,
#                      '_ih': ['', "get_ipython().run_line_magic('pip', 'install b
#                      ioemu')", "get_ipython().run_line_magic('pip', 'install torc
#                      h==2.4.1')", "get_ipython().run_line_magic('pip', 'install b
#                      ioemu')", "from bioemu.sample import main as sample\nsam...
#     ..................................................
#
# File "C:\Users\Леонид\AppData\Local\Temp\ipykernel_4576\2298233248.py", line 2, in <module>
#     1    from bioemu.sample import main as sample
# --> 2    sample(sequence='GYDPETGTWG', num_samples=10, output_dir='~/test_chignolin')
#     ..................................................
#      sample = <function 'main' _contextlib.py:113>
#     ..................................................
#
# File "c:\Anaconda\Lib\site-packages\torch\utils\_contextlib.py", line 116, in decorate_context
#     113  @functools.wraps(func)
#     114  def decorate_context(*args, **kwargs):
#     115      with ctx_factory():
# --> 116          return func(*args, **kwargs)
#     ..................................................
#      functools.wraps = <function 'wraps' functools.py:65>
#      func = <function 'main' sample.py:64>
#      args = ()
#      kwargs = {'sequence': 'GYDPETGTWG',
#                'num_samples': 10,
#                'output_dir': '~/test_chignolin'}
#      ctx_factory = <method '_DecoratorContextManager.clone' of <torch.autograd.
#                     grad_mode.no_grad object at 0x0000016C5E81C2F0> _contextlib.
#                     py:146>
#     ..................................................
#
# File "c:\Anaconda\Lib\site-packages\bioemu\sample.py", line 166, in main
#     65   def main(
#     66       sequence: str | Path,
#     67       num_samples: int,
#     68       output_dir: str | Path,
#     69       batch_size_100: int = 10,
#     70       model_name: str | None = "bioemu-v1.0",
#     71       ckpt_path: str | Path | None = None,
#     72       model_config_path: str | Path | None = None,
#     73       denoiser_type: SupportedDenoisersLiteral | None = "dpm",
#     74       denoiser_config_path: str | Path | None = None,
#     75       cache_embeds_dir: str | Path | None = None,
#     76       msa_host_url: str | None = None,
#     77       filter_samples: bool = True,
#     78   ) -> None:
#  (...)
#     162              raise ValueError(
#     163                  f"Not sure why {npz_path} already exists when so far only {existing_num_samples} samples have been generated."
#     164              )
#     165          logger.info(f"Sampling {seed=}")
# --> 166          batch = generate_batch(
#     167              score_model=score_model,
#     ..................................................
#      sequence = 'GYDPETGTWG'
#      num_samples = 10
#      output_dir = WindowsPath('C:/Users/Леонид/test_chignolin')
#      batch_size_100 = 10
#      model_name = 'bioemu-v1.0'
#      ckpt_path = 'C:\\Users\\Леонид\\.cache\\huggingface\\hub\\models--micros
#                   oft--bioemu\\snapshots\\5c7f0de2dcc700a8820e9b98b97058c682c2
#                   6f38\\checkpoints\\bioemu-v1.0\\checkpoint.ckpt'
#      model_config_path = 'C:\\Users\\Леонид\\.cache\\huggingface\\hub\\models--micros
#                           oft--bioemu\\snapshots\\5c7f0de2dcc700a8820e9b98b97058c682c2
#                           6f38\\checkpoints\\bioemu-v1.0\\config.yaml'
#      denoiser_type = 'dpm'
#      denoiser_config_path = WindowsPath('c:/Anaconda/Lib/site-packages/bioemu/config/den
#                              oiser/dpm.yaml')
#      cache_embeds_dir = None
#      msa_host_url = None
#      filter_samples = True
#      npz_path = WindowsPath('C:/Users/Леонид/test_chignolin/batch_0000000_00
#                  00010.npz')
#      existing_num_samples = 0
#      logger.info = <method 'Logger.info' of <Logger bioemu.sample (WARNING)> __
#                     init__.py:1529>
#      seed = 0
#     ..................................................
#
# File "c:\Anaconda\Lib\site-packages\bioemu\sample.py", line 227, in generate_batch
#     200  def generate_batch(
#     201      score_model: torch.nn.Module,
#     202      sequence: str,
#     203      sdes: dict[str, SDE],
#     204      batch_size: int,
#     205      seed: int,
#     206      denoiser: Callable,
#     207      cache_embeds_dir: str | Path | None,
#     208      msa_file: str | Path | None = None,
#     209      msa_host_url: str | None = None,
#     210  ) -> dict[str, torch.Tensor]:
#  (...)
#     223
#     224      torch.manual_seed(seed)
#     225      n = len(sequence)
#     226
# --> 227      single_embeds_file, pair_embeds_file = get_colabfold_embeds(
#     228          seq=sequence,
#     ..................................................
#      sequence = 'GYDPETGTWG'
#      sdes = {'node_orientations': DiGSO3SDE(
#               (igso3): SampleIGSO3()
#               (uso3): SampleUSO3()
#               (score_function): ScoreSO3()
#             ), 'pos': <bioemu.sde_lib.CosineVPSDE object at 0x0000016C5E
#              DB60C0>}
#      batch_size = 10
#      seed = 0
#      cache_embeds_dir = None
#      msa_file = None
#      msa_host_url = None
#      torch.manual_seed = <function 'manual_seed' _compile.py:21>
#      n = 10
#     ..................................................
#
# File "c:\Anaconda\Lib\site-packages\bioemu\get_embeds.py", line 160, in get_colabfold_embeds
#     124  def get_colabfold_embeds(
#     125      seq: str,
#     126      cache_embeds_dir: StrPath | None,
#     127      msa_file: StrPath | None = None,
#     128      msa_host_url: str | None = None,
#     129  ) -> tuple[StrPath, StrPath]:
#  (...)
#     156          return single_rep_file, pair_rep_file
#     157
#     158      # If we don't already have embeds, run colabfold
#     159      colabfold_dir = _get_colabfold_install_dir()
# --> 160      colabfold_bin_dir = ensure_colabfold_install(colabfold_dir=colabfold_dir)
#     161
#     ..................................................
#      seq = 'GYDPETGTWG'
#      cache_embeds_dir = 'C:\\Users\\Леонид\\.localcolabfold\\embeds_cache'
#      StrPath = str | os.PathLike
#      msa_file = None
#      msa_host_url = None
#      single_rep_file = 'C:\\Users\\Леонид\\.localcolabfold\\embeds_cache\\539b322ba
#                         cb5376ca1c0a5ccad3196eb77b38dae8a09ae4a6cb83f40826936a7_sing
#                         le.npy'
#      pair_rep_file = 'C:\\Users\\Леонид\\.localcolabfold\\embeds_cache\\539b322ba
#                       cb5376ca1c0a5ccad3196eb77b38dae8a09ae4a6cb83f40826936a7_pair
#                       .npy'
#      colabfold_dir = 'C:\\Users\\Леонид\\.localcolabfold'
#     ..................................................
#
# File "c:\Anaconda\Lib\site-packages\bioemu\get_embeds.py", line 75, in ensure_colabfold_install
#     54   def ensure_colabfold_install(colabfold_dir: StrPath) -> str:
#  (...)
#     71               stdout=subprocess.PIPE,
#     72               stderr=subprocess.STDOUT,
#     73           )
#     74           assert (
# --> 75               _install.returncode == 0
#     76           ), f"Something went wrong during colabfold install: {_install.stdout.decode()}"
#     ..................................................
#      colabfold_dir = 'C:\\Users\\Леонид\\.localcolabfold'
#      StrPath = str | os.PathLike
#      subprocess.PIPE = -1
#      subprocess.STDOUT = -2
#      _install.returncode = 127
#     ..................................................
#
# ---- (full traceback above) ----
# File "c:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
# File "C:\Users\Леонид\AppData\Local\Temp\ipykernel_4576\2298233248.py", line 2, in <module>
#     sample(sequence='GYDPETGTWG', num_samples=10, output_dir='~/test_chignolin')
# File "c:\Anaconda\Lib\site-packages\torch\utils\_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
# File "c:\Anaconda\Lib\site-packages\bioemu\sample.py", line 166, in main
#     batch = generate_batch(
# File "c:\Anaconda\Lib\site-packages\bioemu\sample.py", line 227, in generate_batch
#     single_embeds_file, pair_embeds_file = get_colabfold_embeds(
# File "c:\Anaconda\Lib\site-packages\bioemu\get_embeds.py", line 160, in get_colabfold_embeds
#     colabfold_bin_dir = ensure_colabfold_install(colabfold_dir=colabfold_dir)
# File "c:\Anaconda\Lib\site-packages\bioemu\get_embeds.py", line 75, in ensure_colabfold_install
#     _install.returncode == 0
#
# AssertionError: Something went wrong during colabfold install: /bin/bash: C:AnacondaLibsite-packagesbioemucolabfold_setupsetup.sh: No such file or directory
