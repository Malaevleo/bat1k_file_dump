# %%
import Bio
import os
import pandas as pd
from Bio import SeqIO

# Define the directory containing your FASTA files
input_dir = 'mitimpair_codons'

# Define the output directory to save the filtered files
output_dir = 'mitimpair_codons_filtered'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Iterate over all files in the input directory
for filename in os.listdir(input_dir):
    # Process only FASTA files (adjust the extensions if necessary)
    if filename.endswith('.fasta') or filename.endswith('.fa') or filename.endswith('.fas'):
        input_filepath = os.path.join(input_dir, filename)
        output_filepath = os.path.join(output_dir, filename)
        
        # Read all sequences from the input FASTA file
        with open(input_filepath, 'r') as input_handle:
            sequences = list(SeqIO.parse(input_handle, 'fasta'))
        
        # Filter out sequences whose IDs start with 'en'
        filtered_sequences = [seq for seq in sequences if not seq.id.startswith('en')]
        
        # Write the filtered sequences to the output file
        with open(output_filepath, 'w') as output_handle:
            SeqIO.write(filtered_sequences, output_handle, 'fasta')
        
        # Print a summary
        num_removed = len(sequences) - len(filtered_sequences)
        print(f"Processed {filename}: {num_removed} sequences removed.")
# Out:
# Processed EAW70196.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001153583.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001177793.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001179.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001184044.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001186768.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001188.1_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed NP_001274364.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001275684.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001278360.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001289201.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001304107.1_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed NP_001308657.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001308926.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001309749.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001310513.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001317309.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001339859.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001341754.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001352690.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001361015.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001362219.1_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed NP_001363732.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001364194.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001364230.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001365933.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001372664.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_001387053.1_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed NP_001397864.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_004322.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_004620.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_054765.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_056195.3_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_057155.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_060762.3_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_061764.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_115682.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_116205.3_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_116784.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_203526.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed NP_852090.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed O00411.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed O60220.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed O60296.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed O75431.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed O96008.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed P14406.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed P20336.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed P42765.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed P48507.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed P49406.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed P52815.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed P56181.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed P82663.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q12887.3_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed Q13084.4_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q13405.1_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed Q13794.1_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed Q14296.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q15070.4_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q15388.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q8IXM3.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q8TCC3.1_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed Q8WV93.2_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed Q96EL2.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q96GC5.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q99689.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9BQ48.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9BYD1.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9NQ50.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9NZE8.3_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9UDX5.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9UH62.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9UQM7.2_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9Y2Z2.2_bat_only_aligned_nucleotide.fasta: 0 sequences removed.
# Processed Q9Y5Z4.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed Q9Y6G3.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed XP_054208573.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.
# Processed XP_054220447.1_bat_only_aligned_nucleotide.fasta: 1 sequences removed.

# %%
from ete3 import Tree
from Bio import SeqIO
import os

# Paths
full_tree_file = "bat_tags_noen.nwk"  # Path to the full tree file
pal2nal_dir = "mitimpair_pal2nal_noen"  # Directory with cleaned codon-aligned files
output_tree_dir = "mitimpair_trees_noen"  # Directory to store pruned trees

# Species tag to full name mapping
tag_to_species = {
    "rf": "Rhinolophus_ferrumequinum",
    "dr": "Desmodus_rotundus",
    "ra": "Rousettus_aegyptiacus",
    "pv": "Pteropus_vampyrus",
    "pg": "Pteropus_giganteus",
    "pa": "Pteropus_alecto",
    "pk": "Pipistrellus_kuhlii",
    "ph": "Phyllostomus_hastatus",
    "pd": "Phyllostomus_discolor",
    "mm": "Myotis_myotis",
    "ml": "Myotis_lucifugus",
    "mb": "Myotis_brandtii",
    "mo": "Molossus_molossus",
    "md": "Myotis_daubentonii",
    "sb": "Saccopteryx_bilineata",
    "aj": "Artibeus_jamaicensis",
    "pn": "Pipistrellus_nathusii",
    "en": "Eptesicus_nilssonii",
}

# Create output directory if it doesn't exist
os.makedirs(output_tree_dir, exist_ok=True)

# Load the full tree
full_tree = Tree(full_tree_file, format=1)

# Process each alignment file
for alignment_file in os.listdir(pal2nal_dir):
    if alignment_file.endswith(".fasta"):
        alignment_path = os.path.join(pal2nal_dir, alignment_file)

        # Check if the file is empty
        if os.stat(alignment_path).st_size == 0:
            print(f"Skipping empty file: {alignment_file}")
            continue

        print(f"\nProcessing: {alignment_file}")

        # Extract sequence names from the alignment
        sequence_names = {}
        for record in SeqIO.parse(alignment_path, "fasta"):
            tag = record.id[:2]  # Extract the first two letters of the record ID
            if tag in tag_to_species:
                species_name = tag_to_species[tag]
                sequence_names[species_name] = record.id
            else:
                print(f"Warning: Unrecognized tag '{tag}' in {record.id}")

        # Debugging: Print extracted sequence names
        print(f"Extracted sequence names for {alignment_file}:")
        for species, seq_id in sequence_names.items():
            print(f"  {species}: {seq_id}")

        # Copy the full tree for modification
        unique_tree = full_tree.copy()

        # Rename leaves to match sequence names and remove unmatched leaves
        unmatched_leaves = []
        for leaf in unique_tree.get_leaves():
            if leaf.name in sequence_names:
                leaf.name = sequence_names[leaf.name]  # Rename leaf to match sequence ID
            else:
                unmatched_leaves.append(leaf.name)

        # Debugging: Print unmatched leaves
        if unmatched_leaves:
            print(f"Unmatched leaves for {alignment_file}: {unmatched_leaves}")

        # Remove unmatched leaves
        for leaf_name in unmatched_leaves:
            leaf = unique_tree.search_nodes(name=leaf_name)[0]
            leaf.detach()

        # Save the unique tree
        output_tree_path = os.path.join(output_tree_dir, f"{alignment_file}_pruned.nwk")
        unique_tree.write(outfile=output_tree_path, format=1)
        print(f"Unique tree saved to: {output_tree_path}")
# Out:
# Processing: EAW70196.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for EAW70196.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Pipistrellus_nathusii: pnCAK6448204.1
#   Rhinolophus_ferrumequinum: rfXP_032967603.1
#   Molossus_molossus: moXP_036110306.1
#   Saccopteryx_bilineata: sbXP_066089324.1
#   Myotis_myotis: mmXP_036174461.1
#   Myotis_daubentonii: mdXP_059558664.1
#   Myotis_brandtii: mbXP_005873631.1
#   Myotis_lucifugus: mlXP_006082442.1
#   Pipistrellus_kuhlii: pkXP_036276778.1
#   Rousettus_aegyptiacus: raXP_015986601.1
#   Pteropus_vampyrus: pvXP_023391721.1
#   Pteropus_giganteus: pgXP_039700286.1
#   Pteropus_alecto: paXP_006921389.1
#   Desmodus_rotundus: drXP_024419726.2
#   Artibeus_jamaicensis: ajXP_037023424.2
#   Phyllostomus_hastatus: phXP_045703543.1
#   Phyllostomus_discolor: pdXP_028365372.1
# Unique tree saved to: mitimpair_trees_noen\EAW70196.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: NP_001153583.1_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: NP_001177793.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001177793.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032974452.1
#   Pteropus_vampyrus: pvXP_011361410.1
#   Pteropus_giganteus: pgXP_039738368.1
#   Pteropus_alecto: paXP_006912773.1
#   Desmodus_rotundus: drXP_045039974.1
#   Saccopteryx_bilineata: sbXP_066114118.1
#   Pipistrellus_nathusii: pnCAK6443584.1
#   Myotis_myotis: mmXP_036155245.1
#   Myotis_daubentonii: mdXP_059538446.1
#   Myotis_lucifugus: mlXP_023608084.1
#   Myotis_brandtii: mbXP_014399725.1
#   Molossus_molossus: moXP_036107883.1
#   Rousettus_aegyptiacus: raXP_015989577.2
#   Phyllostomus_hastatus: phXP_045685660.1
#   Phyllostomus_discolor: pdXP_035875118.1
#   Artibeus_jamaicensis: ajXP_053517602.1
#   Pipistrellus_kuhlii: pkXP_036310884.1
# Unique tree saved to: mitimpair_trees_noen\NP_001177793.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001179.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001179.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Phyllostomus_discolor: pdXP_028365967.2
#   Myotis_myotis: mmXP_036212503.1
#   Rhinolophus_ferrumequinum: rfXP_032959238.1
#   Rousettus_aegyptiacus: raXP_016002456.2
#   Pteropus_giganteus: pgXP_039712235.1
#   Pteropus_alecto: paXP_006907426.1
#   Pteropus_vampyrus: pvXP_023394266.1
#   Saccopteryx_bilineata: sbXP_066133924.1
#   Desmodus_rotundus: drXP_024413611.2
#   Artibeus_jamaicensis: ajXP_036990341.2
#   Phyllostomus_hastatus: phXP_045691039.1
#   Molossus_molossus: moXP_036105141.1
#   Pipistrellus_nathusii: pnCAK6447098.1
#   Pipistrellus_kuhlii: pkXP_036270610.1
#   Myotis_brandtii: mbXP_005878084.1
#   Myotis_daubentonii: mdXP_059557951.1
#   Myotis_lucifugus: mlXP_014322089.1
# Unique tree saved to: mitimpair_trees_noen\NP_001179.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001184044.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001184044.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032952995.1
#   Pipistrellus_nathusii: pnCAK6446875.1
#   Pipistrellus_kuhlii: pkXP_036269926.1
#   Rousettus_aegyptiacus: raXP_016009361.1
#   Pteropus_vampyrus: pvXP_011377392.1
#   Pteropus_giganteus: pgXP_039709057.1
#   Pteropus_alecto: paXP_006926495.1
#   Desmodus_rotundus: drXP_024413820.2
#   Artibeus_jamaicensis: ajXP_037015447.1
#   Phyllostomus_hastatus: phXP_045699081.1
#   Phyllostomus_discolor: pdXP_028365132.1
#   Saccopteryx_bilineata: sbXP_066108794.1
#   Myotis_myotis: mmXP_036172238.1
#   Myotis_daubentonii: mdXP_059557385.1
#   Molossus_molossus: moXP_036104227.1
#   Myotis_brandtii: mbXP_005878145.1
#   Myotis_lucifugus: mlXP_006108155.1
# Unique tree saved to: mitimpair_trees_noen\NP_001184044.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001186768.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001186768.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032965006.1
#   Desmodus_rotundus: drXP_024412574.1
#   Rousettus_aegyptiacus: raXP_015975977.1
#   Artibeus_jamaicensis: ajXP_053510820.1
#   Saccopteryx_bilineata: sbXP_066133569.1
#   Myotis_daubentonii: mdXP_059564106.1
#   Molossus_molossus: moXP_036122826.1
#   Myotis_brandtii: mbXP_014385438.1
#   Myotis_lucifugus: mlXP_023619475.1
#   Myotis_myotis: mmXP_036211327.1
#   Phyllostomus_discolor: pdXP_035886126.1
#   Phyllostomus_hastatus: phXP_045697253.1
#   Pipistrellus_kuhlii: pkXP_036304910.2
#   Pteropus_alecto: paXP_006913650.1
#   Pteropus_giganteus: pgXP_039707385.1
#   Pteropus_vampyrus: pvXP_011371114.1
#   Pipistrellus_nathusii: pnCAK6432506.1
# Unique tree saved to: mitimpair_trees_noen\NP_001186768.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: NP_001188.1_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: NP_001274364.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001274364.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Molossus_molossus: moXP_036130948.1
#   Pipistrellus_kuhlii: pkXP_036296391.1
#   Rhinolophus_ferrumequinum: rfXP_032984480.1
#   Saccopteryx_bilineata: sbXP_066098987.1
#   Myotis_myotis: mmXP_036201828.1
#   Myotis_daubentonii: mdXP_059522974.1
#   Pipistrellus_nathusii: pnCAK6436908.1
#   Rousettus_aegyptiacus: raXP_015988754.2
#   Pteropus_vampyrus: pvXP_011370152.1
#   Pteropus_giganteus: pgXP_039744525.1
#   Pteropus_alecto: paXP_006926847.1
#   Desmodus_rotundus: drXP_024433325.2
#   Artibeus_jamaicensis: ajXP_036995039.2
#   Phyllostomus_hastatus: phXP_045702893.1
#   Phyllostomus_discolor: pdXP_028386128.1
#   Myotis_brandtii: mbXP_014395140.1
#   Myotis_lucifugus: mlXP_014317455.1
# Unique tree saved to: mitimpair_trees_noen\NP_001274364.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001275684.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001275684.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032946005.1
#   Desmodus_rotundus: drXP_024420423.2
#   Artibeus_jamaicensis: ajXP_036999232.2
#   Phyllostomus_hastatus: phXP_045692135.1
#   Phyllostomus_discolor: pdXP_028375397.1
#   Pipistrellus_nathusii: pnCAK6437980.1
#   Pipistrellus_kuhlii: pkXP_036310153.1
#   Myotis_daubentonii: mdXP_059525517.1
#   Myotis_myotis: mmXP_036196431.1
#   Myotis_lucifugus: mlXP_006099930.1
#   Myotis_brandtii: mbXP_014404351.1
#   Saccopteryx_bilineata: sbXP_066119409.1
#   Rousettus_aegyptiacus: raXP_016008006.1
#   Pteropus_vampyrus: pvXP_011358325.1
#   Pteropus_giganteus: pgXP_039741955.1
#   Pteropus_alecto: paXP_006925036.1
#   Molossus_molossus: moXP_036123882.1
# Unique tree saved to: mitimpair_trees_noen\NP_001275684.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001278360.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001278360.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032983483.1
#   Desmodus_rotundus: drXP_045056372.1
#   Phyllostomus_discolor: pdXP_035868408.1
#   Phyllostomus_hastatus: phXP_045712303.1
#   Artibeus_jamaicensis: ajXP_036986785.2
#   Myotis_brandtii: mbXP_014405992.1
#   Myotis_daubentonii: mdXP_059521903.1
#   Myotis_myotis: mmXP_036163150.1
#   Pipistrellus_nathusii: pnCAK6437308.1
#   Pipistrellus_kuhlii: pkXP_045433137.1
#   Molossus_molossus: moXP_036130710.1
#   Rousettus_aegyptiacus: raXP_015977886.2
#   Pteropus_vampyrus: pvXP_011372877.1
#   Pteropus_giganteus: pgXP_039724454.1
#   Pteropus_alecto: paXP_015448117.1
#   Saccopteryx_bilineata: sbXP_066127687.1
#   Myotis_lucifugus: mlXP_023604791.1
# Unique tree saved to: mitimpair_trees_noen\NP_001278360.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001289201.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001289201.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032987136.1
#   Pipistrellus_nathusii: pnCAK6436054.1
#   Pipistrellus_kuhlii: pkXP_036295110.1
#   Desmodus_rotundus: drXP_024411127.2
#   Artibeus_jamaicensis: ajXP_036988784.2
#   Saccopteryx_bilineata: sbXP_066095962.1
#   Molossus_molossus: moXP_036120894.1
#   Rousettus_aegyptiacus: raXP_015998015.2
#   Pteropus_vampyrus: pvXP_011357535.1
#   Pteropus_giganteus: pgXP_039726811.1
#   Pteropus_alecto: paXP_006920881.1
#   Myotis_daubentonii: mdXP_059540436.1
#   Myotis_lucifugus: mlXP_006101274.1
#   Myotis_brandtii: mbXP_005879735.1
#   Myotis_myotis: mmXP_036191702.1
#   Phyllostomus_hastatus: phXP_045710067.1
#   Phyllostomus_discolor: pdXP_028368309.1
# Unique tree saved to: mitimpair_trees_noen\NP_001289201.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: NP_001304107.1_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: NP_001308657.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001308657.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Pipistrellus_nathusii: pnCAK6435233.1
#   Rhinolophus_ferrumequinum: rfXP_032980946.1
#   Rousettus_aegyptiacus: raXP_015986175.1
#   Pteropus_vampyrus: pvXP_011356396.1
#   Pteropus_giganteus: pgXP_039708641.1
#   Pteropus_alecto: paXP_006905279.1
#   Desmodus_rotundus: drXP_024414344.2
#   Phyllostomus_hastatus: phXP_045683590.1
#   Phyllostomus_discolor: pdXP_028373468.1
#   Artibeus_jamaicensis: ajXP_036986725.1
#   Saccopteryx_bilineata: sbXP_066123573.1
#   Molossus_molossus: moXP_036118140.1
#   Pipistrellus_kuhlii: pkXP_036291694.1
#   Myotis_myotis: mmXP_036189921.1
#   Myotis_daubentonii: mdXP_059515330.1
#   Myotis_lucifugus: mlXP_006096863.1
#   Myotis_brandtii: mbXP_014397734.1
# Unique tree saved to: mitimpair_trees_noen\NP_001308657.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: NP_001308926.1_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: NP_001309749.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001309749.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032958685.1
#   Molossus_molossus: moXP_036104303.1
#   Pipistrellus_nathusii: pnCAK6446478.1
#   Pipistrellus_kuhlii: pkXP_036270912.1
#   Myotis_myotis: mmXP_036172316.1
#   Myotis_daubentonii: mdXP_059555893.1
#   Myotis_lucifugus: mlXP_014301611.2
#   Myotis_brandtii: mbXP_005852824.1
#   Rousettus_aegyptiacus: raXP_016008203.1
#   Pteropus_vampyrus: pvXP_011378660.1
#   Pteropus_giganteus: pgXP_039729854.1
#   Pteropus_alecto: paXP_006915094.1
#   Desmodus_rotundus: drXP_053770007.1
#   Artibeus_jamaicensis: ajXP_036982039.2
#   Phyllostomus_hastatus: phXP_045699399.1
#   Phyllostomus_discolor: pdXP_028365393.1
#   Saccopteryx_bilineata: sbXP_066103796.1
# Unique tree saved to: mitimpair_trees_noen\NP_001309749.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001310513.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001310513.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Pipistrellus_nathusii: pnCAK6436362.1
#   Rhinolophus_ferrumequinum: rfXP_032987089.1
#   Rousettus_aegyptiacus: raXP_015988574.2
#   Pteropus_vampyrus: pvXP_011370455.1
#   Pteropus_giganteus: pgXP_039727915.1
#   Pteropus_alecto: paXP_006915624.1
#   Molossus_molossus: moXP_036121653.1
#   Saccopteryx_bilineata: sbXP_066098163.1
#   Myotis_daubentonii: mdXP_059518493.1
#   Myotis_myotis: mmXP_036192831.1
#   Myotis_brandtii: mbXP_005876884.1
#   Myotis_lucifugus: mlXP_014304756.1
#   Pipistrellus_kuhlii: pkXP_045437754.1
#   Desmodus_rotundus: drXP_024417051.2
#   Phyllostomus_hastatus: phXP_045697994.1
#   Phyllostomus_discolor: pdXP_028368991.1
#   Artibeus_jamaicensis: ajXP_036986516.2
# Unique tree saved to: mitimpair_trees_noen\NP_001310513.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001317309.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001317309.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Molossus_molossus: moXP_036108674.1
#   Pipistrellus_nathusii: pnCAK6443563.1
#   Pipistrellus_kuhlii: pkXP_036313504.1
#   Rhinolophus_ferrumequinum: rfXP_032972294.1
#   Desmodus_rotundus: drXP_024431244.1
#   Pteropus_alecto: paXP_024903198.1
#   Phyllostomus_hastatus: phXP_045685976.1
#   Artibeus_jamaicensis: ajXP_053517459.1
#   Phyllostomus_discolor: pdXP_028388535.1
#   Myotis_daubentonii: mdXP_059538518.1
#   Myotis_myotis: mmXP_036157333.1
#   Rousettus_aegyptiacus: raXP_036092556.1
#   Pteropus_vampyrus: pvXP_023388172.1
#   Pteropus_giganteus: pgXP_039738270.1
#   Saccopteryx_bilineata: sbXP_066114182.1
#   Myotis_brandtii: mbXP_014394712.1
#   Myotis_lucifugus: mlXP_014309509.1
# Unique tree saved to: mitimpair_trees_noen\NP_001317309.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001339859.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001339859.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032980135.1
#   Rousettus_aegyptiacus: raXP_036081090.1
#   Pteropus_alecto: paXP_006910323.1
#   Pteropus_giganteus: pgXP_039743717.1
#   Desmodus_rotundus: drXP_024408260.1
#   Artibeus_jamaicensis: ajXP_037007708.2
#   Phyllostomus_hastatus: phXP_045700335.1
#   Phyllostomus_discolor: pdXP_028372056.1
#   Molossus_molossus: moXP_036118789.1
#   Saccopteryx_bilineata: sbXP_066093982.1
#   Pipistrellus_nathusii: pnCAK6434888.1
#   Pipistrellus_kuhlii: pkXP_036290563.1
#   Myotis_myotis: mmXP_036191149.1
#   Myotis_lucifugus: mlXP_006091776.1
#   Myotis_brandtii: mbXP_005875002.1
#   Myotis_daubentonii: mdXP_059516457.1
#   Pteropus_vampyrus: pvXP_023384270.1
# Unique tree saved to: mitimpair_trees_noen\NP_001339859.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001341754.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001341754.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032962155.1
#   Rousettus_aegyptiacus: raXP_036083449.1
#   Pteropus_vampyrus: pvXP_011363519.1
#   Pteropus_alecto: paXP_006919019.1
#   Pteropus_giganteus: pgXP_039694009.1
#   Desmodus_rotundus: drXP_024429715.1
#   Artibeus_jamaicensis: ajXP_053528294.1
#   Phyllostomus_hastatus: phXP_045689997.1
#   Phyllostomus_discolor: pdXP_028361428.1
#   Pipistrellus_kuhlii: pkXP_036275327.1
#   Pipistrellus_nathusii: pnCAK6433262.1
#   Myotis_myotis: mmXP_036186069.1
#   Myotis_lucifugus: mlXP_006093335.1
#   Myotis_brandtii: mbXP_005877725.1
#   Myotis_daubentonii: mdXP_059530320.1
#   Saccopteryx_bilineata: sbXP_066134951.1
#   Molossus_molossus: moXP_036137128.1
# Unique tree saved to: mitimpair_trees_noen\NP_001341754.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001352690.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001352690.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032989728.1
#   Pipistrellus_nathusii: pnCAK6445594.1
#   Pipistrellus_kuhlii: pkXP_036315412.1
#   Myotis_myotis: mmXP_036170407.1
#   Myotis_daubentonii: mdXP_059553032.1
#   Myotis_lucifugus: mlXP_006101152.1
#   Myotis_brandtii: mbXP_005884449.1
#   Molossus_molossus: moXP_036096596.1
#   Desmodus_rotundus: drXP_024424753.1
#   Phyllostomus_hastatus: phXP_045686737.1
#   Phyllostomus_discolor: pdXP_028377339.1
#   Artibeus_jamaicensis: ajXP_037021151.2
#   Saccopteryx_bilineata: sbXP_066130946.1
#   Rousettus_aegyptiacus: raXP_016000430.1
#   Pteropus_alecto: paXP_006904188.1
#   Pteropus_vampyrus: pvXP_023394345.1
#   Pteropus_giganteus: pgXP_039734389.1
# Unique tree saved to: mitimpair_trees_noen\NP_001352690.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001361015.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001361015.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032967775.1
#   Desmodus_rotundus: drXP_045054127.1
#   Molossus_molossus: moXP_036110135.1
#   Saccopteryx_bilineata: sbXP_066088703.1
#   Artibeus_jamaicensis: ajXP_036988144.2
#   Phyllostomus_hastatus: phXP_045710005.1
#   Phyllostomus_discolor: pdXP_035878748.1
#   Rousettus_aegyptiacus: raXP_036092068.1
#   Pteropus_vampyrus: pvXP_023385543.1
#   Pteropus_alecto: paXP_006906778.1
#   Pteropus_giganteus: pgXP_039700718.1
#   Myotis_lucifugus: mlXP_006082826.2
#   Myotis_myotis: mmXP_036174895.1
#   Myotis_brandtii: mbXP_014386638.1
#   Myotis_daubentonii: mdXP_059559155.1
#   Pipistrellus_nathusii: pnCAK6448090.1
#   Pipistrellus_kuhlii: pkXP_045436392.1
# Unique tree saved to: mitimpair_trees_noen\NP_001361015.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001362219.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001362219.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032961694.1
#   Pteropus_vampyrus: pvXP_011354591.1
#   Pteropus_giganteus: pgXP_039701645.1
#   Pteropus_alecto: paXP_006910792.1
#   Rousettus_aegyptiacus: raXP_016016562.2
#   Desmodus_rotundus: drXP_024430551.1
#   Artibeus_jamaicensis: ajXP_037019156.1
#   Saccopteryx_bilineata: sbXP_066135802.1
#   Phyllostomus_hastatus: phXP_045676240.1
#   Phyllostomus_discolor: pdXP_035882366.1
#   Molossus_molossus: moXP_036116129.1
#   Myotis_daubentonii: mdXP_059521457.1
#   Myotis_lucifugus: mlXP_014307571.1
#   Myotis_brandtii: mbXP_014385763.1
#   Myotis_myotis: mmXP_036195554.1
#   Pipistrellus_nathusii: pnCAK6432973.1
#   Pipistrellus_kuhlii: pkXP_036267349.1
# Unique tree saved to: mitimpair_trees_noen\NP_001362219.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001363732.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001363732.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032971820.1
#   Rousettus_aegyptiacus: raXP_036092913.1
#   Pteropus_vampyrus: pvXP_011361182.1
#   Pteropus_giganteus: pgXP_039713737.1
#   Pteropus_alecto: paXP_015442796.1
#   Desmodus_rotundus: drXP_045055492.2
#   Phyllostomus_hastatus: phXP_045703152.1
#   Phyllostomus_discolor: pdXP_035882384.1
#   Artibeus_jamaicensis: ajXP_037003844.2
#   Molossus_molossus: moXP_036113020.1
#   Saccopteryx_bilineata: sbXP_066124457.1
#   Myotis_myotis: mmXP_036206789.1
#   Myotis_lucifugus: mlXP_014313890.1
#   Myotis_brandtii: mbXP_005878476.1
#   Myotis_daubentonii: mdXP_059544645.1
#   Pipistrellus_nathusii: pnCAK6441403.1
#   Pipistrellus_kuhlii: pkXP_045440242.1
# Unique tree saved to: mitimpair_trees_noen\NP_001363732.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: NP_001364194.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Skipping empty file: NP_001364230.1_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: NP_001365933.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001365933.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032965941.1
#   Desmodus_rotundus: drXP_024419349.1
#   Rousettus_aegyptiacus: raXP_015992627.1
#   Pteropus_vampyrus: pvXP_011373441.1
#   Pteropus_giganteus: pgXP_039713246.1
#   Pteropus_alecto: paXP_006913212.1
#   Artibeus_jamaicensis: ajXP_037019303.2
#   Phyllostomus_hastatus: phXP_045703694.1
#   Phyllostomus_discolor: pdXP_035876323.1
#   Molossus_molossus: moXP_036134786.1
#   Myotis_lucifugus: mlXP_006081378.1
#   Myotis_myotis: mmXP_036165366.1
#   Myotis_daubentonii: mdXP_059550301.1
#   Pipistrellus_nathusii: pnCAK6444323.1
#   Pipistrellus_kuhlii: pkXP_036266408.1
#   Saccopteryx_bilineata: sbXP_066090743.1
#   Myotis_brandtii: mbXP_005858214.1
# Unique tree saved to: mitimpair_trees_noen\NP_001365933.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001372664.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001372664.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032953043.1
#   Molossus_molossus: moXP_036132595.1
#   Rousettus_aegyptiacus: raXP_015982727.1
#   Pteropus_vampyrus: pvXP_011354168.1
#   Pteropus_alecto: paXP_006908671.1
#   Pteropus_giganteus: pgXP_039724247.1
#   Saccopteryx_bilineata: sbXP_066111151.1
#   Desmodus_rotundus: drXP_024422916.3
#   Artibeus_jamaicensis: ajXP_037012159.2
#   Phyllostomus_hastatus: phXP_045699511.1
#   Phyllostomus_discolor: pdXP_028384273.1
#   Pipistrellus_nathusii: pnCAK6440419.1
#   Pipistrellus_kuhlii: pkXP_036305478.1
#   Myotis_lucifugus: mlXP_023616180.1
#   Myotis_myotis: mmXP_036210376.1
#   Myotis_daubentonii: mdXP_059531872.1
#   Myotis_brandtii: mbXP_005852962.2
# Unique tree saved to: mitimpair_trees_noen\NP_001372664.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001387053.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001387053.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Pipistrellus_kuhlii: pkXP_036291813.1
#   Myotis_lucifugus: mlXP_023601054.1
#   Molossus_molossus: moXP_036119000.1
#   Pteropus_giganteus: pgXP_039708298.1
#   Myotis_daubentonii: mdXP_059515229.1
#   Myotis_myotis: mmXP_036189808.1
#   Myotis_brandtii: mbXP_005885697.1
#   Rhinolophus_ferrumequinum: rfXP_032980988.1
#   Desmodus_rotundus: drXP_024414288.1
#   Phyllostomus_hastatus: phXP_045683354.1
#   Phyllostomus_discolor: pdXP_028371051.1
#   Artibeus_jamaicensis: ajXP_037015603.2
#   Saccopteryx_bilineata: sbXP_066123720.1
#   Rousettus_aegyptiacus: raXP_036079852.1
#   Pteropus_vampyrus: pvXP_011368108.1
#   Pteropus_alecto: paXP_006917774.1
#   Pipistrellus_nathusii: pnCAK6435282.1
# Unique tree saved to: mitimpair_trees_noen\NP_001387053.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_001397864.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_001397864.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032986715.1
#   Artibeus_jamaicensis: ajXP_036986420.1
#   Phyllostomus_hastatus: phXP_045697809.1
#   Phyllostomus_discolor: pdXP_035882699.1
#   Saccopteryx_bilineata: sbXP_066098750.1
#   Molossus_molossus: moXP_036121254.1
#   Desmodus_rotundus: drXP_024416795.1
#   Rousettus_aegyptiacus: raXP_016012424.1
#   Pteropus_vampyrus: pvXP_011353529.1
#   Pteropus_alecto: paXP_006915581.1
#   Pteropus_giganteus: pgXP_039728041.1
#   Myotis_lucifugus: mlXP_014312624.1
#   Myotis_brandtii: mbXP_014393896.1
#   Myotis_myotis: mmXP_036192970.1
#   Myotis_daubentonii: mdXP_059518380.1
#   Pipistrellus_nathusii: pnCAK6436409.1
#   Pipistrellus_kuhlii: pkXP_036293711.1
# Unique tree saved to: mitimpair_trees_noen\NP_001397864.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_004322.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_004322.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Phyllostomus_discolor: pdXP_028375203.1
#   Rhinolophus_ferrumequinum: rfXP_032990674.1
#   Pteropus_vampyrus: pvXP_023386510.1
#   Pteropus_giganteus: pgXP_039732085.1
#   Pteropus_alecto: paXP_024906169.1
#   Molossus_molossus: moXP_036137889.1
#   Rousettus_aegyptiacus: raXP_016009779.1
#   Saccopteryx_bilineata: sbXP_066123222.1
#   Myotis_lucifugus: mlXP_006095087.1
#   Myotis_daubentonii: mdXP_059551924.1
#   Pipistrellus_nathusii: pnCAK6445218.1
#   Pipistrellus_kuhlii: pkXP_045441875.1
#   Desmodus_rotundus: drXP_053766978.1
#   Phyllostomus_hastatus: phXP_045709102.1
#   Artibeus_jamaicensis: ajXP_037023005.2
#   Myotis_brandtii: mbXP_014389106.1
#   Myotis_myotis: mmXP_036168168.1
# Unique tree saved to: mitimpair_trees_noen\NP_004322.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_004620.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_004620.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rousettus_aegyptiacus: raXP_036094958.1
#   Saccopteryx_bilineata: sbXP_066112948.1
#   Pipistrellus_nathusii: pnCAK6433857.1
#   Desmodus_rotundus: drXP_045051104.2
#   Artibeus_jamaicensis: ajXP_053512245.1
#   Rhinolophus_ferrumequinum: rfXP_032978290.1
#   Pteropus_vampyrus: pvXP_011379756.1
#   Pteropus_giganteus: pgXP_039731412.1
#   Pteropus_alecto: paXP_006916088.1
#   Phyllostomus_hastatus: phXP_045696430.1
#   Phyllostomus_discolor: pdXP_035877766.1
#   Pipistrellus_kuhlii: pkXP_036289364.1
#   Myotis_myotis: mmXP_036186381.1
#   Myotis_daubentonii: mdXP_059513224.1
#   Myotis_lucifugus: mlXP_023618217.1
#   Myotis_brandtii: mbXP_014386950.1
#   Molossus_molossus: moXP_036116902.1
# Unique tree saved to: mitimpair_trees_noen\NP_004620.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_054765.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_054765.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Saccopteryx_bilineata: sbXP_066109938.1
#   Pipistrellus_nathusii: pnCAK6447205.1
#   Rhinolophus_ferrumequinum: rfXP_032958499.1
#   Desmodus_rotundus: drXP_024413783.2
#   Phyllostomus_hastatus: phXP_045681876.1
#   Phyllostomus_discolor: pdXP_028365394.1
#   Artibeus_jamaicensis: ajXP_036997231.2
#   Rousettus_aegyptiacus: raXP_015976146.2
#   Pteropus_vampyrus: pvXP_011382280.1
#   Pteropus_giganteus: pgXP_039707099.1
#   Pteropus_alecto: paXP_006913717.1
#   Myotis_lucifugus: mlXP_023600952.1
#   Myotis_daubentonii: mdXP_059558158.1
#   Myotis_myotis: mmXP_036212179.1
#   Myotis_brandtii: mbXP_005863314.1
#   Pipistrellus_kuhlii: pkXP_045434298.1
#   Molossus_molossus: moXP_036103627.1
# Unique tree saved to: mitimpair_trees_noen\NP_054765.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_056195.3_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_056195.3_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Myotis_lucifugus: mlXP_023603834.1
#   Myotis_brandtii: mbXP_014390617.1
#   Myotis_myotis: mmXP_036154687.1
#   Myotis_daubentonii: mdXP_059537397.1
#   Rhinolophus_ferrumequinum: rfXP_032973329.1
#   Rousettus_aegyptiacus: raXP_015991233.1
#   Pteropus_giganteus: pgXP_039719164.1
#   Pteropus_alecto: paXP_006917399.1
#   Desmodus_rotundus: drXP_045042827.2
#   Phyllostomus_hastatus: phXP_045691109.1
#   Phyllostomus_discolor: pdXP_028388279.1
#   Saccopteryx_bilineata: sbXP_066111890.1
#   Artibeus_jamaicensis: ajXP_037016420.1
#   Molossus_molossus: moXP_036108627.1
#   Pipistrellus_kuhlii: pkXP_036276122.1
#   Pipistrellus_nathusii: pnCAK6444009.1
#   Pteropus_vampyrus: pvXP_023380608.1
# Unique tree saved to: mitimpair_trees_noen\NP_056195.3_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_057155.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_057155.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032955160.1
#   Rousettus_aegyptiacus: raXP_015988494.1
#   Pteropus_vampyrus: pvXP_011357779.1
#   Pteropus_giganteus: pgXP_039716902.1
#   Pteropus_alecto: paXP_006910532.1
#   Molossus_molossus: moXP_036103013.1
#   Desmodus_rotundus: drXP_024410819.1
#   Artibeus_jamaicensis: ajXP_036994790.1
#   Phyllostomus_hastatus: phXP_045711750.1
#   Phyllostomus_discolor: pdXP_035866858.1
#   Saccopteryx_bilineata: sbXP_066118563.1
#   Pipistrellus_nathusii: pnCAK6434393.1
#   Pipistrellus_kuhlii: pkXP_045433494.1
#   Myotis_daubentonii: mdXP_059567977.1
#   Myotis_myotis: mmXP_036184428.1
#   Myotis_brandtii: mbXP_005875077.1
#   Myotis_lucifugus: mlXP_006094777.1
# Unique tree saved to: mitimpair_trees_noen\NP_057155.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: NP_060762.3_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: NP_061764.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_061764.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Phyllostomus_hastatus: phXP_045677232.1
#   Phyllostomus_discolor: pdXP_028382439.1
#   Rhinolophus_ferrumequinum: rfXP_032960682.1
#   Rousettus_aegyptiacus: raXP_015999291.2
#   Pteropus_vampyrus: pvXP_011376726.1
#   Pteropus_giganteus: pgXP_039733234.1
#   Pteropus_alecto: paXP_006915033.1
#   Saccopteryx_bilineata: sbXP_066091389.1
#   Desmodus_rotundus: drXP_024434481.1
#   Artibeus_jamaicensis: ajXP_036985435.2
#   Pipistrellus_nathusii: pnCAK6442531.1
#   Pipistrellus_kuhlii: pkXP_045437617.1
#   Myotis_myotis: mmXP_036155055.1
#   Myotis_daubentonii: mdXP_059541808.1
#   Myotis_brandtii: mbXP_005880724.1
#   Molossus_molossus: moXP_036106132.1
# Unmatched leaves for NP_061764.2_bat_only_aligned_nucleotide_codon_aligned.fasta: ['Myotis_lucifugus']
# Unique tree saved to: mitimpair_trees_noen\NP_061764.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_115682.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_115682.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032990344.1
#   Desmodus_rotundus: drXP_024424814.2
#   Artibeus_jamaicensis: ajXP_037021275.2
#   Phyllostomus_hastatus: phXP_045687313.1
#   Phyllostomus_discolor: pdXP_028376331.1
#   Rousettus_aegyptiacus: raXP_016000723.2
#   Pteropus_vampyrus: pvXP_011371894.1
#   Pteropus_giganteus: pgXP_039734433.1
#   Pteropus_alecto: paXP_006904201.1
#   Molossus_molossus: moXP_036096315.1
#   Pipistrellus_nathusii: pnCAK6445580.1
#   Pipistrellus_kuhlii: pkXP_036315974.1
#   Myotis_myotis: mmXP_036169183.1
#   Myotis_lucifugus: mlXP_014321934.1
#   Myotis_brandtii: mbXP_014387355.1
#   Myotis_daubentonii: mdXP_059552933.1
#   Saccopteryx_bilineata: sbXP_066130575.1
# Unique tree saved to: mitimpair_trees_noen\NP_115682.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_116205.3_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_116205.3_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Molossus_molossus: moXP_036131428.1
#   Rousettus_aegyptiacus: raXP_015988723.2
#   Pteropus_vampyrus: pvXP_023393423.1
#   Desmodus_rotundus: drXP_053770478.1
#   Phyllostomus_hastatus: phXP_045702680.1
#   Myotis_lucifugus: mlXP_014317467.1
#   Myotis_brandtii: mbXP_014392266.1
#   Pipistrellus_kuhlii: pkXP_036296868.1
#   Artibeus_jamaicensis: ajXP_053526507.1
#   Phyllostomus_discolor: pdXP_028385239.1
#   Rhinolophus_ferrumequinum: rfXP_032984822.1
#   Pteropus_giganteus: pgXP_039744533.1
#   Pteropus_alecto: paXP_006926841.1
#   Myotis_myotis: mmXP_036202425.1
#   Myotis_daubentonii: mdXP_059523001.1
#   Pipistrellus_nathusii: pnCAK6436901.1
#   Saccopteryx_bilineata: sbXP_066098819.1
# Unique tree saved to: mitimpair_trees_noen\NP_116205.3_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_116784.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_116784.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Saccopteryx_bilineata: sbXP_066107988.1
#   Artibeus_jamaicensis: ajXP_036996060.2
#   Pipistrellus_kuhlii: pkXP_036273266.1
#   Rhinolophus_ferrumequinum: rfXP_032975623.1
#   Rousettus_aegyptiacus: raXP_015974042.1
#   Pteropus_vampyrus: pvXP_011367031.1
#   Pteropus_giganteus: pgXP_039716040.1
#   Pteropus_alecto: paXP_006911212.1
#   Desmodus_rotundus: drXP_045039185.1
#   Phyllostomus_hastatus: phXP_045710874.1
#   Phyllostomus_discolor: pdXP_028371570.1
#   Pipistrellus_nathusii: pnCAK6449680.1
#   Myotis_myotis: mmXP_036182701.1
#   Myotis_brandtii: mbXP_005864251.1
#   Myotis_daubentonii: mdXP_059566254.1
#   Myotis_lucifugus: mlXP_006106608.1
#   Molossus_molossus: moXP_036114491.1
# Unique tree saved to: mitimpair_trees_noen\NP_116784.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_203526.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_203526.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032985136.1
#   Desmodus_rotundus: drXP_024433406.1
#   Rousettus_aegyptiacus: raXP_016020745.1
#   Pteropus_vampyrus: pvXP_023393699.1
#   Pteropus_giganteus: pgXP_039710552.1
#   Pteropus_alecto: paXP_006911757.1
#   Molossus_molossus: moXP_036131308.1
#   Pipistrellus_nathusii: pnCAK6437028.1
#   Pipistrellus_kuhlii: pkXP_036264285.1
#   Myotis_daubentonii: mdXP_059522620.1
#   Myotis_myotis: mmXP_036205304.1
#   Myotis_lucifugus: mlXP_023616353.1
#   Myotis_brandtii: mbXP_005886025.1
#   Saccopteryx_bilineata: sbXP_066098782.1
#   Artibeus_jamaicensis: ajXP_036988924.1
#   Phyllostomus_hastatus: phXP_045702635.1
#   Phyllostomus_discolor: pdXP_028385629.1
# Unique tree saved to: mitimpair_trees_noen\NP_203526.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: NP_852090.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for NP_852090.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032979832.1
#   Pipistrellus_kuhlii: pkXP_036289765.1
#   Pipistrellus_nathusii: pnCAK6433975.1
#   Myotis_myotis: mmXP_036186807.1
#   Myotis_daubentonii: mdXP_059512837.1
#   Myotis_brandtii: mbXP_014396790.1
#   Myotis_lucifugus: mlXP_006101126.1
#   Desmodus_rotundus: drXP_053779923.1
#   Artibeus_jamaicensis: ajXP_037013494.1
#   Phyllostomus_hastatus: phXP_045696434.1
#   Phyllostomus_discolor: pdXP_028374321.1
#   Saccopteryx_bilineata: sbXP_066113231.1
#   Rousettus_aegyptiacus: raXP_036073732.1
#   Pteropus_vampyrus: pvXP_023380357.1
#   Pteropus_alecto: paXP_024907179.1
#   Molossus_molossus: moXP_036117861.1
# Unmatched leaves for NP_852090.1_bat_only_aligned_nucleotide_codon_aligned.fasta: ['Pteropus_giganteus']
# Unique tree saved to: mitimpair_trees_noen\NP_852090.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: O00411.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for O00411.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032989758.1
#   Rousettus_aegyptiacus: raXP_036090157.1
#   Pteropus_vampyrus: pvXP_023376242.1
#   Pteropus_giganteus: pgXP_039694947.1
#   Pteropus_alecto: paXP_015455022.1
#   Desmodus_rotundus: drXP_024424804.2
#   Artibeus_jamaicensis: ajXP_036994965.2
#   Phyllostomus_hastatus: phXP_045686780.1
#   Phyllostomus_discolor: pdXP_028375909.1
#   Molossus_molossus: moXP_036098012.1
#   Saccopteryx_bilineata: sbXP_066134428.1
#   Myotis_myotis: mmXP_036169703.1
#   Myotis_daubentonii: mdXP_059553462.1
#   Myotis_lucifugus: mlXP_006101869.1
#   Myotis_brandtii: mbXP_014395538.1
#   Pipistrellus_kuhlii: pkXP_036280949.1
#   Pipistrellus_nathusii: pnCAK6445738.1
# Unique tree saved to: mitimpair_trees_noen\O00411.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: O60220.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for O60220.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032966004.1
#   Desmodus_rotundus: drXP_024434508.1
#   Molossus_molossus: moXP_036126983.1
#   Saccopteryx_bilineata: sbXP_066105034.1
#   Artibeus_jamaicensis: ajXP_036986918.1
#   Phyllostomus_discolor: pdXP_028379039.1
#   Rousettus_aegyptiacus: raXP_015987689.1
#   Pteropus_vampyrus: pvXP_011382108.1
#   Pteropus_alecto: paXP_006920756.1
#   Pteropus_giganteus: pgXP_039729933.1
#   Phyllostomus_hastatus: phXP_045673667.1
#   Pipistrellus_kuhlii: pkXP_036295890.1
#   Myotis_brandtii: mbXP_005873431.1
#   Myotis_myotis: mmXP_036161533.1
#   Myotis_lucifugus: mlXP_006084740.1
#   Pipistrellus_nathusii: pnCAK6450397.1
#   Myotis_daubentonii: mdXP_059536532.1
# Unique tree saved to: mitimpair_trees_noen\O60220.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: O60296.2_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: O75431.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for O75431.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Myotis_daubentonii: mdXP_059559982.1
#   Myotis_brandtii: mbXP_005857672.1
#   Rhinolophus_ferrumequinum: rfXP_032968756.1
#   Pteropus_vampyrus: pvXP_011355318.1
#   Pteropus_giganteus: pgXP_039711169.1
#   Pteropus_alecto: paXP_015452224.1
#   Rousettus_aegyptiacus: raXP_015989971.1
#   Desmodus_rotundus: drXP_045052203.1
#   Phyllostomus_hastatus: phXP_045687332.1
#   Phyllostomus_discolor: pdXP_028365607.1
#   Artibeus_jamaicensis: ajXP_036985925.1
#   Molossus_molossus: moXP_036110685.1
#   Pipistrellus_nathusii: pnCAK6448461.1
#   Myotis_myotis: mmXP_036175277.1
#   Pipistrellus_kuhlii: pkXP_036277397.1
#   Saccopteryx_bilineata: sbXP_066135483.1
#   Myotis_lucifugus: mlXP_023600385.1
# Unique tree saved to: mitimpair_trees_noen\O75431.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: O96008.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for O96008.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Myotis_brandtii: mbXP_005863468.1
#   Rhinolophus_ferrumequinum: rfXP_032983902.1
#   Myotis_lucifugus: mlXP_023602727.1
#   Desmodus_rotundus: drXP_024425295.2
#   Phyllostomus_hastatus: phXP_045701182.1
#   Phyllostomus_discolor: pdXP_028385840.1
#   Artibeus_jamaicensis: ajXP_036981880.1
#   Molossus_molossus: moXP_036130685.1
#   Pteropus_vampyrus: pvXP_011366271.1
#   Pteropus_giganteus: pgXP_039722104.1
#   Pipistrellus_kuhlii: pkXP_036284602.1
#   Pipistrellus_nathusii: pnCAK6437176.1
#   Rousettus_aegyptiacus: raXP_016005678.1
#   Myotis_daubentonii: mdXP_059522186.1
#   Myotis_myotis: mmXP_036201727.1
#   Pteropus_alecto: paXP_006911849.1
#   Saccopteryx_bilineata: sbXP_066127941.1
# Unique tree saved to: mitimpair_trees_noen\O96008.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: P14406.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for P14406.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032959283.1
#   Desmodus_rotundus: drXP_024432385.1
#   Rousettus_aegyptiacus: raXP_015997171.2
#   Pteropus_vampyrus: pvXP_011381860.1
#   Pteropus_giganteus: pgXP_039709096.1
#   Saccopteryx_bilineata: sbXP_066109090.1
#   Pteropus_alecto: paXP_006926438.1
#   Artibeus_jamaicensis: ajXP_037003325.1
#   Phyllostomus_discolor: pdXP_028364468.1
#   Phyllostomus_hastatus: phXP_045699851.1
#   Molossus_molossus: moXP_036104371.1
#   Pipistrellus_nathusii: pnCAK6446828.1
#   Pipistrellus_kuhlii: pkXP_036269556.1
#   Myotis_daubentonii: mdXP_059557148.1
#   Myotis_myotis: mmXP_036173133.1
#   Myotis_brandtii: mbXP_014391268.1
#   Myotis_lucifugus: mlXP_023610053.1
# Unique tree saved to: mitimpair_trees_noen\P14406.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: P20336.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for P20336.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032990338.1
#   Rousettus_aegyptiacus: raXP_016022021.1
#   Pipistrellus_nathusii: pnCAK6445318.1
#   Artibeus_jamaicensis: ajXP_036997923.1
#   Saccopteryx_bilineata: sbXP_066125832.1
#   Myotis_daubentonii: mdXP_059552195.1
#   Molossus_molossus: moXP_036097942.1
#   Myotis_brandtii: mbXP_005873932.1
#   Myotis_lucifugus: mlXP_006100418.1
#   Myotis_myotis: mmXP_036167676.1
#   Phyllostomus_discolor: pdXP_035888483.1
#   Pteropus_vampyrus: pvXP_011365103.1
#   Pipistrellus_kuhlii: pkXP_036306026.1
#   Pteropus_alecto: paXP_006904364.1
#   Pteropus_giganteus: pgXP_039723803.1
#   Phyllostomus_hastatus: phXP_045709307.1
#   Desmodus_rotundus: drXP_053771008.1
# Unique tree saved to: mitimpair_trees_noen\P20336.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: P42765.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for P42765.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032943685.1
#   Pteropus_vampyrus: pvXP_011359056.1
#   Pteropus_giganteus: pgXP_039697843.1
#   Pteropus_alecto: paXP_024894448.1
#   Desmodus_rotundus: drXP_024436328.2
#   Phyllostomus_hastatus: phXP_045706252.1
#   Artibeus_jamaicensis: ajXP_037020975.1
#   Phyllostomus_discolor: pdXP_028379986.1
#   Saccopteryx_bilineata: sbXP_066102709.1
#   Molossus_molossus: moXP_036101533.1
#   Pipistrellus_kuhlii: pkXP_036274842.1
#   Pipistrellus_nathusii: pnCAK6447954.1
#   Myotis_myotis: mmXP_036178837.1
#   Myotis_lucifugus: mlXP_006085155.1
#   Myotis_daubentonii: mdXP_059563241.1
#   Rousettus_aegyptiacus: raXP_036085929.1
#   Myotis_brandtii: mbXP_005853031.1
# Unique tree saved to: mitimpair_trees_noen\P42765.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: P48507.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for P48507.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032970850.1
#   Rousettus_aegyptiacus: raXP_015989709.1
#   Pteropus_giganteus: pgXP_039730729.1
#   Pteropus_alecto: paXP_006919485.1
#   Pteropus_vampyrus: pvXP_023383893.1
#   Saccopteryx_bilineata: sbXP_066124800.1
#   Desmodus_rotundus: drXP_024421303.1
#   Artibeus_jamaicensis: ajXP_037017943.2
#   Molossus_molossus: moXP_036112085.1
#   Phyllostomus_hastatus: phXP_045703016.1
#   Phyllostomus_discolor: pdXP_028369193.1
#   Pipistrellus_nathusii: pnCAK6441354.1
#   Pipistrellus_kuhlii: pkXP_036301491.1
#   Myotis_myotis: mmXP_036204183.1
#   Myotis_daubentonii: mdXP_059544772.1
#   Myotis_brandtii: mbXP_014405535.1
#   Myotis_lucifugus: mlXP_023617614.1
# Unique tree saved to: mitimpair_trees_noen\P48507.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: P49406.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for P49406.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Pipistrellus_nathusii: pnCAK6435242.1
#   Rhinolophus_ferrumequinum: rfXP_032981246.1
#   Rousettus_aegyptiacus: raXP_015986126.2
#   Pteropus_vampyrus: pvXP_011356384.1
#   Pteropus_giganteus: pgXP_039708333.1
#   Pteropus_alecto: paXP_006905289.1
#   Molossus_molossus: moXP_036118868.1
#   Pipistrellus_kuhlii: pkXP_036291740.1
#   Myotis_daubentonii: mdXP_059515306.1
#   Myotis_myotis: mmXP_036189903.1
#   Myotis_lucifugus: mlXP_006102991.1
#   Myotis_brandtii: mbXP_005853174.1
#   Saccopteryx_bilineata: sbXP_066123581.1
#   Desmodus_rotundus: drXP_024414295.2
#   Phyllostomus_hastatus: phXP_045684853.1
#   Phyllostomus_discolor: pdXP_028372310.1
#   Artibeus_jamaicensis: ajXP_036986716.2
# Unique tree saved to: mitimpair_trees_noen\P49406.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: P52815.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for P52815.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032944932.1
#   Rousettus_aegyptiacus: raXP_016019355.1
#   Pteropus_vampyrus: pvXP_011371998.1
#   Pteropus_alecto: paXP_015445049.1
#   Desmodus_rotundus: drXP_024409693.2
#   Artibeus_jamaicensis: ajXP_037013594.2
#   Phyllostomus_hastatus: phXP_045692109.1
#   Phyllostomus_discolor: pdXP_028376576.1
#   Molossus_molossus: moXP_036124947.1
#   Pipistrellus_kuhlii: pkXP_036268269.1
#   Pipistrellus_nathusii: pnCAK6438618.1
#   Myotis_myotis: mmXP_036198054.1
#   Myotis_daubentonii: mdXP_059527509.1
#   Myotis_brandtii: mbXP_014386752.1
#   Saccopteryx_bilineata: sbXP_066090953.1
#   Pteropus_giganteus: pgXP_039715790.1
#   Myotis_lucifugus: mlXP_006109297.1
# Unique tree saved to: mitimpair_trees_noen\P52815.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: P56181.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for P56181.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032990117.1
#   Rousettus_aegyptiacus: raXP_015998959.2
#   Pteropus_giganteus: pgXP_039713713.1
#   Desmodus_rotundus: drXP_024417714.1
#   Artibeus_jamaicensis: ajXP_037000473.1
#   Phyllostomus_hastatus: phXP_045708549.1
#   Phyllostomus_discolor: pdXP_028360769.1
#   Myotis_lucifugus: mlXP_006103960.1
#   Myotis_daubentonii: mdXP_059542548.1
#   Pipistrellus_kuhlii: pkXP_036302605.1
#   Molossus_molossus: moXP_036099642.1
#   Saccopteryx_bilineata: sbXP_066115386.1
#   Pteropus_vampyrus: pvXP_023388450.1
#   Pteropus_alecto: paXP_015451928.1
#   Myotis_myotis: mmXP_036207362.1
# Unmatched leaves for P56181.2_bat_only_aligned_nucleotide_codon_aligned.fasta: ['Myotis_brandtii', 'Pipistrellus_nathusii']
# Unique tree saved to: mitimpair_trees_noen\P56181.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: P82663.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for P82663.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032988015.1
#   Pipistrellus_nathusii: pnCAK6435588.1
#   Pipistrellus_kuhlii: pkXP_036287114.1
#   Myotis_brandtii: mbXP_005870085.1
#   Myotis_daubentonii: mdXP_059519688.1
#   Molossus_molossus: moXP_036123219.1
#   Myotis_lucifugus: mlXP_006083862.1
#   Desmodus_rotundus: drXP_024412189.1
#   Artibeus_jamaicensis: ajXP_053525066.1
#   Phyllostomus_hastatus: phXP_045687878.1
#   Phyllostomus_discolor: pdXP_028374310.1
#   Saccopteryx_bilineata: sbXP_066101758.1
#   Pteropus_alecto: paXP_006907229.1
#   Rousettus_aegyptiacus: raXP_015977530.1
#   Pteropus_vampyrus: pvXP_023384844.1
#   Pteropus_giganteus: pgXP_039693305.1
# Unmatched leaves for P82663.1_bat_only_aligned_nucleotide_codon_aligned.fasta: ['Myotis_myotis']
# Unique tree saved to: mitimpair_trees_noen\P82663.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q12887.3_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q12887.3_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Pipistrellus_nathusii: pnCAK6437637.1
#   Rhinolophus_ferrumequinum: rfXP_032946585.1
#   Rousettus_aegyptiacus: raXP_016016699.1
#   Pteropus_vampyrus: pvXP_023385722.1
#   Pteropus_alecto: paXP_024900118.1
#   Pteropus_giganteus: pgXP_039703333.1
#   Molossus_molossus: moXP_036125668.1
#   Desmodus_rotundus: drXP_024420410.1
#   Artibeus_jamaicensis: ajXP_037010590.2
#   Phyllostomus_discolor: pdXP_028390347.1
#   Myotis_myotis: mmXP_036197632.1
#   Myotis_daubentonii: mdXP_059524550.1
#   Myotis_brandtii: mbXP_005857404.1
#   Myotis_lucifugus: mlXP_006097436.1
#   Pipistrellus_kuhlii: pkXP_036307808.1
#   Phyllostomus_hastatus: phXP_045680457.1
#   Saccopteryx_bilineata: sbXP_066120383.1
# Unique tree saved to: mitimpair_trees_noen\Q12887.3_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q13084.4_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q13084.4_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032957302.1
#   Desmodus_rotundus: drXP_024409173.1
#   Artibeus_jamaicensis: ajXP_037013121.2
#   Phyllostomus_hastatus: phXP_045704740.1
#   Phyllostomus_discolor: pdXP_028369151.1
#   Molossus_molossus: moXP_036134744.1
#   Myotis_daubentonii: mdXP_059548503.1
#   Myotis_myotis: mmXP_036159063.1
#   Myotis_lucifugus: mlXP_006103735.1
#   Myotis_brandtii: mbXP_005870419.1
#   Saccopteryx_bilineata: sbXP_066131535.1
#   Rousettus_aegyptiacus: raXP_036081870.1
#   Pteropus_vampyrus: pvXP_011375050.1
#   Pteropus_giganteus: pgXP_039740660.1
#   Pteropus_alecto: paXP_006914089.1
#   Pipistrellus_nathusii: pnCAK6444896.1
#   Pipistrellus_kuhlii: pkXP_045426264.1
# Unique tree saved to: mitimpair_trees_noen\Q13084.4_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q13405.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q13405.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032975975.1
#   Desmodus_rotundus: drXP_024429971.2
#   Artibeus_jamaicensis: ajXP_037002415.1
#   Phyllostomus_hastatus: phXP_045710918.1
#   Phyllostomus_discolor: pdXP_028371204.1
#   Rousettus_aegyptiacus: raXP_015974879.1
#   Pteropus_vampyrus: pvXP_011367097.1
#   Pteropus_alecto: paXP_015444351.1
#   Pteropus_giganteus: pgXP_039696915.1
#   Molossus_molossus: moXP_036114614.1
#   Saccopteryx_bilineata: sbXP_066108100.1
#   Myotis_myotis: mmXP_036182605.1
#   Myotis_lucifugus: mlXP_006104412.1
#   Myotis_daubentonii: mdXP_059566145.1
#   Myotis_brandtii: mbXP_005864283.1
#   Pipistrellus_nathusii: pnCAK6449716.1
#   Pipistrellus_kuhlii: pkXP_036286346.1
# Unique tree saved to: mitimpair_trees_noen\Q13405.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q13794.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q13794.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Pipistrellus_nathusii: pnCAK6447693.1
#   Rhinolophus_ferrumequinum: rfXP_032943375.1
#   Saccopteryx_bilineata: sbXP_066102731.1
#   Desmodus_rotundus: drXP_053769378.1
#   Phyllostomus_hastatus: phXP_045706068.1
#   Phyllostomus_discolor: pdXP_028380811.1
#   Artibeus_jamaicensis: ajXP_037007897.1
#   Pipistrellus_kuhlii: pkXP_036274910.1
#   Myotis_daubentonii: mdXP_059562222.1
#   Myotis_lucifugus: mlXP_006087212.1
#   Myotis_brandtii: mbXP_005881863.1
#   Myotis_myotis: mmXP_036179003.1
# ...
#   Desmodus_rotundus: drXP_024417506.2
#   Pipistrellus_nathusii: pnCAK6442258.1
#   Artibeus_jamaicensis: ajXP_037023871.1
#   Saccopteryx_bilineata: sbXP_066091532.1
#   Myotis_daubentonii: mdXP_059533350.1
#   Molossus_molossus: moXP_036133350.1
#   Rousettus_aegyptiacus: raXP_016018911.1
#   Myotis_lucifugus: mlXP_006104565.1
#   Myotis_myotis: mmXP_036211107.1
#   Phyllostomus_discolor: pdXP_028387164.1
#   Phyllostomus_hastatus: phXP_045672438.1
#   Pipistrellus_kuhlii: pkXP_036309464.1
#   Pteropus_alecto: paXP_006920790.1
#   Pteropus_giganteus: pgXP_039706235.1
#   Myotis_brandtii: mbXP_005881404.1
#   Pteropus_vampyrus: pvXP_023375547.1
# Unique tree saved to: mitimpair_trees_noen\Q15388.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q8IXM3.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q8IXM3.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032979042.1
#   Rousettus_aegyptiacus: raXP_015986483.1
#   Pteropus_vampyrus: pvXP_011384857.1
#   Pteropus_giganteus: pgXP_039714968.1
#   Pteropus_alecto: paXP_006918198.1
#   Saccopteryx_bilineata: sbXP_066111699.1
#   Pipistrellus_kuhlii: pkXP_036272864.1
#   Pipistrellus_nathusii: pnCAK6433449.1
#   Myotis_myotis: mmXP_036162740.1
#   Desmodus_rotundus: drXP_024418080.1
#   Phyllostomus_hastatus: phXP_045702101.1
#   Phyllostomus_discolor: pdXP_028375008.1
#   Artibeus_jamaicensis: ajXP_036983515.2
#   Molossus_molossus: moXP_036117749.1
# Unmatched leaves for Q8IXM3.1_bat_only_aligned_nucleotide_codon_aligned.fasta: ['Myotis_brandtii', 'Myotis_lucifugus', 'Myotis_daubentonii']
# Unique tree saved to: mitimpair_trees_noen\Q8IXM3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q8TCC3.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q8TCC3.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032981482.1
#   Rousettus_aegyptiacus: raXP_036080237.1
#   Pteropus_vampyrus: pvXP_023380994.1
#   Pteropus_giganteus: pgXP_039723086.1
#   Pteropus_alecto: paXP_006916251.1
#   Saccopteryx_bilineata: sbXP_066123910.1
#   Molossus_molossus: moXP_036128527.1
#   Pipistrellus_nathusii: pnCAK6439690.1
#   Pipistrellus_kuhlii: pkXP_036297961.1
#   Myotis_brandtii: mbXP_005862432.1
#   Myotis_myotis: mmXP_036200237.1
#   Myotis_daubentonii: mdXP_059531404.1
#   Myotis_lucifugus: mlXP_014316475.1
#   Desmodus_rotundus: drXP_024433948.2
#   Phyllostomus_hastatus: phXP_045682925.1
#   Phyllostomus_discolor: pdXP_035884198.1
#   Artibeus_jamaicensis: ajXP_036982578.2
# Unique tree saved to: mitimpair_trees_noen\Q8TCC3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: Q8WV93.2_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: Q96EL2.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q96EL2.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032944032.1
#   Rousettus_aegyptiacus: raXP_016003313.1
#   Pteropus_vampyrus: pvXP_011383036.1
#   Pteropus_giganteus: pgXP_039702971.1
#   Pteropus_alecto: paXP_006911526.1
#   Desmodus_rotundus: drXP_053767753.1
#   Artibeus_jamaicensis: ajXP_053516593.1
#   Phyllostomus_hastatus: phXP_045715171.1
#   Phyllostomus_discolor: pdXP_028369095.1
#   Pipistrellus_nathusii: pnCAK6434820.1
#   Pipistrellus_kuhlii: pkXP_036292150.1
#   Myotis_daubentonii: mdXP_059512003.1
#   Myotis_myotis: mmXP_036183017.1
#   Myotis_lucifugus: mlXP_006106854.1
#   Myotis_brandtii: mbXP_005882988.1
#   Saccopteryx_bilineata: sbXP_066106768.1
#   Molossus_molossus: moXP_036103049.1
# Unique tree saved to: mitimpair_trees_noen\Q96EL2.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q96GC5.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q96GC5.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032977595.1
#   Desmodus_rotundus: drXP_024428346.2
#   Myotis_daubentonii: mdXP_059564472.1
#   Myotis_myotis: mmXP_036180917.1
#   Myotis_brandtii: mbXP_005867152.1
#   Myotis_lucifugus: mlXP_006100523.1
#   Artibeus_jamaicensis: ajXP_037004595.2
#   Phyllostomus_hastatus: phXP_045673718.1
#   Phyllostomus_discolor: pdXP_035885884.1
#   Pipistrellus_nathusii: pnCAK6448996.1
#   Pipistrellus_kuhlii: pkXP_036282555.1
#   Rousettus_aegyptiacus: raXP_016016906.1
#   Pteropus_vampyrus: pvXP_011375679.1
#   Pteropus_giganteus: pgXP_039703956.1
#   Pteropus_alecto: paXP_006926663.1
#   Molossus_molossus: moXP_036114287.1
#   Saccopteryx_bilineata: sbXP_066106295.1
# Unique tree saved to: mitimpair_trees_noen\Q96GC5.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q99689.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q99689.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032954214.1
#   Rousettus_aegyptiacus: raXP_015978145.1
#   Pteropus_vampyrus: pvXP_011365433.1
#   Pteropus_giganteus: pgXP_039728717.1
#   Pteropus_alecto: paXP_015447486.1
#   Desmodus_rotundus: drXP_024413080.1
#   Phyllostomus_discolor: pdXP_028384816.1
#   Phyllostomus_hastatus: phXP_045716236.1
#   Saccopteryx_bilineata: sbXP_066111091.1
#   Artibeus_jamaicensis: ajXP_053515428.1
#   Molossus_molossus: moXP_036132700.1
#   Pipistrellus_nathusii: pnCAK6440313.1
#   Pipistrellus_kuhlii: pkXP_045441420.1
#   Myotis_myotis: mmXP_036210066.1
#   Myotis_daubentonii: mdXP_059531764.1
#   Myotis_lucifugus: mlXP_023599026.1
#   Myotis_brandtii: mbXP_005870966.1
# Unique tree saved to: mitimpair_trees_noen\Q99689.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q9BQ48.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9BQ48.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032989423.1
#   Rousettus_aegyptiacus: raXP_016013160.1
#   Pteropus_vampyrus: pvXP_011365145.1
#   Pteropus_giganteus: pgXP_039723720.1
#   Pteropus_alecto: paXP_006904336.1
#   Pipistrellus_nathusii: pnCAK6445350.1
#   Pipistrellus_kuhlii: pkXP_036271959.1
#   Myotis_myotis: mmXP_036158569.1
#   Myotis_daubentonii: mdXP_059552288.1
#   Myotis_lucifugus: mlXP_006099732.1
#   Myotis_brandtii: mbXP_005856762.1
#   Desmodus_rotundus: drXP_024416618.1
#   Molossus_molossus: moXP_036097123.1
#   Artibeus_jamaicensis: ajXP_036997868.1
#   Phyllostomus_hastatus: phXP_045709196.1
#   Phyllostomus_discolor: pdXP_028376635.1
#   Saccopteryx_bilineata: sbXP_066126453.1
# Unique tree saved to: mitimpair_trees_noen\Q9BQ48.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q9BYD1.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9BYD1.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032981769.1
#   Pteropus_giganteus: pgXP_039709638.1
#   Rousettus_aegyptiacus: raXP_016012082.1
#   Saccopteryx_bilineata: sbXP_066121846.1
#   Molossus_molossus: moXP_036119903.1
#   Myotis_myotis: mmXP_036194069.1
#   Myotis_lucifugus: mlXP_014308169.1
#   Myotis_brandtii: mbXP_005885928.1
#   Myotis_daubentonii: mdXP_059527789.1
#   Pipistrellus_nathusii: pnCAK6438836.1
#   Pipistrellus_kuhlii: pkXP_036292778.1
#   Desmodus_rotundus: drXP_024428054.2
#   Artibeus_jamaicensis: ajXP_037022588.1
#   Phyllostomus_discolor: pdXP_028389747.1
#   Phyllostomus_hastatus: phXP_045717556.1
#   Pteropus_vampyrus: pvXP_023386732.1
#   Pteropus_alecto: paXP_024905865.1
# Unique tree saved to: mitimpair_trees_noen\Q9BYD1.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q9NQ50.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9NQ50.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Myotis_daubentonii: mdXP_059532923.1
#   Rhinolophus_ferrumequinum: rfXP_032953002.1
#   Rousettus_aegyptiacus: raXP_016022400.2
#   Pteropus_vampyrus: pvXP_023390497.1
#   Pteropus_giganteus: pgXP_039728844.1
#   Pteropus_alecto: paXP_015447503.1
#   Saccopteryx_bilineata: sbXP_066115974.1
#   Desmodus_rotundus: drXP_045048624.1
#   Artibeus_jamaicensis: ajXP_036997486.1
#   Phyllostomus_hastatus: phXP_045675691.1
#   Phyllostomus_discolor: pdXP_028384167.1
#   Molossus_molossus: moXP_036132036.1
#   Myotis_brandtii: mbXP_005875654.2
#   Myotis_myotis: mmXP_036209665.1
#   Myotis_lucifugus: mlXP_023604836.1
#   Pipistrellus_nathusii: pnCAK6440273.1
#   Pipistrellus_kuhlii: pkXP_045441460.1
# Unique tree saved to: mitimpair_trees_noen\Q9NQ50.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q9NZE8.3_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9NZE8.3_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032980992.1
#   Rousettus_aegyptiacus: raXP_015992021.2
#   Pteropus_vampyrus: pvXP_011368100.1
#   Pteropus_giganteus: pgXP_039708302.1
#   Pteropus_alecto: paXP_006917775.1
#   Desmodus_rotundus: drXP_024414361.1
#   Artibeus_jamaicensis: ajXP_037015605.2
#   Phyllostomus_hastatus: phXP_045683361.1
#   Phyllostomus_discolor: pdXP_028373421.1
#   Saccopteryx_bilineata: sbXP_066123738.1
#   Molossus_molossus: moXP_036119025.1
#   Myotis_daubentonii: mdXP_059515254.1
#   Myotis_myotis: mmXP_036189797.1
#   Myotis_lucifugus: mlXP_006104060.1
#   Myotis_brandtii: mbXP_005885692.1
#   Pipistrellus_nathusii: pnCAK6435283.1
#   Pipistrellus_kuhlii: pkXP_036291846.1
# Unique tree saved to: mitimpair_trees_noen\Q9NZE8.3_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
# Skipping empty file: Q9UDX5.1_bat_only_aligned_nucleotide_codon_aligned.fasta
#
# Processing: Q9UH62.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9UH62.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032959857.1
#   Rousettus_aegyptiacus: raXP_015987668.1
#   Pteropus_vampyrus: pvXP_023381010.1
#   Pteropus_giganteus: pgXP_039729922.1
#   Pteropus_alecto: paXP_006920748.1
#   Desmodus_rotundus: drXP_024434513.1
#   Artibeus_jamaicensis: ajXP_036986886.1
#   Myotis_myotis: mmXP_036160997.1
#   Myotis_brandtii: mbXP_005869936.1
#   Myotis_daubentonii: mdXP_059536276.1
#   Myotis_lucifugus: mlXP_014307622.1
#   Phyllostomus_discolor: pdXP_028378265.1
#   Phyllostomus_hastatus: phXP_045673637.1
#   Pipistrellus_nathusii: pnCAK6450405.1
#   Pipistrellus_kuhlii: pkXP_045438361.1
#   Molossus_molossus: moXP_036127428.1
#   Saccopteryx_bilineata: sbXP_066105446.1
# Unique tree saved to: mitimpair_trees_noen\Q9UH62.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q9UQM7.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9UQM7.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032952119.1
#   Rousettus_aegyptiacus: raXP_015974243.1
#   Pipistrellus_nathusii: pnCAK6446231.1
#   Artibeus_jamaicensis: ajXP_053521901.1
#   Saccopteryx_bilineata: sbXP_066129097.1
#   Pteropus_alecto: paXP_006906460.1
#   Pipistrellus_kuhlii: pkXP_036279939.1
#   Myotis_brandtii: mbXP_005870536.1
#   Phyllostomus_hastatus: phXP_045675492.1
#   Myotis_myotis: mmXP_036170186.1
#   Phyllostomus_discolor: pdXP_028383852.1
#   Desmodus_rotundus: drXP_024432644.3
#   Molossus_molossus: moXP_036137695.1
#   Myotis_lucifugus: mlXP_023601515.1
#   Pteropus_giganteus: pgXP_039692473.1
#   Myotis_daubentonii: mdXP_059554882.1
#   Pteropus_vampyrus: pvXP_023383692.1
# Unique tree saved to: mitimpair_trees_noen\Q9UQM7.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q9Y2Z2.2_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9Y2Z2.2_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Pipistrellus_nathusii: pnCAK6446834.1
#   Rhinolophus_ferrumequinum: rfXP_032958338.1
#   Saccopteryx_bilineata: sbXP_066109751.1
#   Rousettus_aegyptiacus: raXP_036075331.1
#   Pteropus_vampyrus: pvXP_011379318.1
#   Pteropus_giganteus: pgXP_039709139.1
#   Pteropus_alecto: paXP_015455890.1
#   Pipistrellus_kuhlii: pkXP_036269391.1
#   Myotis_myotis: mmXP_036172564.1
#   Myotis_daubentonii: mdXP_059557159.1
#   Myotis_brandtii: mbXP_005861492.1
#   Myotis_lucifugus: mlXP_014311841.1
#   Desmodus_rotundus: drXP_053769990.1
#   Artibeus_jamaicensis: ajXP_053520029.1
#   Phyllostomus_hastatus: phXP_045700055.1
#   Phyllostomus_discolor: pdXP_028366214.1
#   Molossus_molossus: moXP_036104968.1
# Unique tree saved to: mitimpair_trees_noen\Q9Y2Z2.2_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q9Y5Z4.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9Y5Z4.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Myotis_brandtii: mbXP_014389413.1
#   Myotis_myotis: mmXP_036172482.1
#   Artibeus_jamaicensis: ajXP_053520706.1
#   Rhinolophus_ferrumequinum: rfXP_032953568.1
#   Rousettus_aegyptiacus: raXP_015988170.1
#   Pteropus_vampyrus: pvXP_011354456.1
#   Pteropus_giganteus: pgXP_039725708.1
#   Pteropus_alecto: paXP_006915435.1
#   Saccopteryx_bilineata: sbXP_066103968.1
#   Pipistrellus_kuhlii: pkXP_036271068.1
#   Pipistrellus_nathusii: pnCAK6446635.1
#   Myotis_lucifugus: mlXP_014307360.1
#   Myotis_daubentonii: mdXP_059556451.1
#   Molossus_molossus: moXP_036104795.1
#   Desmodus_rotundus: drXP_024407673.1
#   Phyllostomus_hastatus: phXP_045699241.1
#   Phyllostomus_discolor: pdXP_028365410.1
# Unique tree saved to: mitimpair_trees_noen\Q9Y5Z4.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: Q9Y6G3.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for Q9Y6G3.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032973940.1
#   Pteropus_vampyrus: pvXP_023387333.1
#   Pteropus_alecto: paXP_024896773.1
#   Rousettus_aegyptiacus: raXP_036092623.1
#   Pteropus_giganteus: pgXP_039724979.1
#   Desmodus_rotundus: drXP_024426146.1
#   Phyllostomus_hastatus: phXP_045686531.1
#   Artibeus_jamaicensis: ajXP_053518135.1
#   Phyllostomus_discolor: pdXP_035874462.1
#   Saccopteryx_bilineata: sbXP_066110883.1
#   Molossus_molossus: moXP_036107982.1
#   Myotis_daubentonii: mdXP_059539771.1
#   Pipistrellus_kuhlii: pkXP_036313447.1
#   Pipistrellus_nathusii: pnCAK6443106.1
#   Myotis_myotis: mmXP_036155874.1
#   Myotis_lucifugus: mlXP_014306973.1
#   Myotis_brandtii: mbXP_014401903.1
# Unique tree saved to: mitimpair_trees_noen\Q9Y6G3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: XP_054208573.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for XP_054208573.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Molossus_molossus: moXP_036136753.1
#   Myotis_lucifugus: mlXP_023604926.1
#   Myotis_myotis: mmXP_036165529.1
#   Saccopteryx_bilineata: sbXP_066130079.1
#   Rhinolophus_ferrumequinum: rfXP_032966295.1
#   Desmodus_rotundus: drXP_024419073.1
#   Phyllostomus_hastatus: phXP_045693942.1
#   Phyllostomus_discolor: pdXP_028366013.1
#   Artibeus_jamaicensis: ajXP_037022941.2
#   Myotis_brandtii: mbXP_005866509.1
#   Myotis_daubentonii: mdXP_059549918.1
#   Pipistrellus_nathusii: pnCAK6444419.1
#   Pipistrellus_kuhlii: pkXP_036267287.1
#   Rousettus_aegyptiacus: raXP_036081259.1
#   Pteropus_vampyrus: pvXP_011363454.1
#   Pteropus_alecto: paXP_006913336.1
#   Pteropus_giganteus: pgXP_039704351.1
# Unique tree saved to: mitimpair_trees_noen\XP_054208573.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk
#
# Processing: XP_054220447.1_bat_only_aligned_nucleotide_codon_aligned.fasta
# Extracted sequence names for XP_054220447.1_bat_only_aligned_nucleotide_codon_aligned.fasta:
#   Rhinolophus_ferrumequinum: rfXP_032987073.1
#   Rousettus_aegyptiacus: raXP_016020483.2
#   Saccopteryx_bilineata: sbXP_066099348.1
#   Pipistrellus_nathusii: pnCAK6436443.1
#   Myotis_brandtii: mbXP_014405067.1
#   Pipistrellus_kuhlii: pkXP_036293983.1
#   Phyllostomus_discolor: pdXP_035882648.1
#   Myotis_myotis: mmXP_036193149.1
#   Myotis_daubentonii: mdXP_059518211.1
#   Myotis_lucifugus: mlXP_006100907.1
#   Molossus_molossus: moXP_036121255.1
#   Phyllostomus_hastatus: phXP_045698329.1
#   Artibeus_jamaicensis: ajXP_037011433.2
#   Desmodus_rotundus: drXP_024416997.1
#   Pteropus_giganteus: pgXP_039728149.1
#   Pteropus_alecto: paXP_006915543.1
#   Pteropus_vampyrus: pvXP_011383064.1
# Unique tree saved to: mitimpair_trees_noen\XP_054220447.1_bat_only_aligned_nucleotide_codon_aligned.fasta_pruned.nwk

# %%
import os

# Define the directory containing your .log files
log_dir = 'mitimpair_busted_noen'

# Get a list of all .log files in the directory
log_files = [f for f in os.listdir(log_dir) if f.endswith('.log')]

# Iterate over each log file
for log_file in log_files:
    file_path = os.path.join(log_dir, log_file)
    print(log_file)
    # Read the file and get the last 2 lines
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()
        if len(lines) >= 2:
            last_two_lines = lines[-2:]  # Get the last two lines
        else:
            last_two_lines = lines  # If the file has fewer than 2 lines
        for line in last_two_lines:
            print(line.rstrip())
    print('-' * 80)  # Separator line
# Out:
# EAW70196.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0259**.
# --------------------------------------------------------------------------------
# NP_001177793.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
#
# Check errors.log for execution error details.
# --------------------------------------------------------------------------------
# NP_001179.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# model-averaged inference, or rerunning the alignment with data at that
# site masked to confirm robustness of the result.
# --------------------------------------------------------------------------------
# NP_001184044.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# NP_001186768.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4205**.
# --------------------------------------------------------------------------------
# NP_001274364.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# NP_001275684.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# NP_001278360.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# performing model-averaged inference, or rerunning the alignment with
# data at that site masked to confirm robustness of the result.
# --------------------------------------------------------------------------------
# NP_001289201.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4996**.
# --------------------------------------------------------------------------------
# NP_001308657.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.3632**.
# --------------------------------------------------------------------------------
# NP_001309749.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4823**.
# --------------------------------------------------------------------------------
# NP_001310513.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
#
# Check errors.log for execution error details.
# --------------------------------------------------------------------------------
# NP_001317309.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
#
# Check errors.log for execution error details.
# --------------------------------------------------------------------------------
# NP_001339859.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# NP_001341754.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# NP_001352690.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.3285**.
# --------------------------------------------------------------------------------
# NP_001361015.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# performing model-averaged inference, or rerunning the alignment with
# data at that site masked to confirm robustness of the result.
# --------------------------------------------------------------------------------
# NP_001362219.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# NP_001363732.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4626**.
# --------------------------------------------------------------------------------
# NP_001365933.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
#
# Check errors.log for execution error details.
# --------------------------------------------------------------------------------
# NP_001372664.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.3951**.
# --------------------------------------------------------------------------------
# NP_001387053.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0049**.
# --------------------------------------------------------------------------------
# NP_001397864.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# model-averaged inference, or rerunning the alignment with data at that
# site masked to confirm robustness of the result.
# --------------------------------------------------------------------------------
# NP_004322.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# performing model-averaged inference, or rerunning the alignment with
# data at that site masked to confirm robustness of the result.
# --------------------------------------------------------------------------------
# NP_004620.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0000**.
# --------------------------------------------------------------------------------
# NP_054765.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0274**.
# --------------------------------------------------------------------------------
# NP_056195.3_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0000**.
# --------------------------------------------------------------------------------
# NP_057155.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4144**.
# --------------------------------------------------------------------------------
# NP_061764.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# NP_115682.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0000**.
# --------------------------------------------------------------------------------
# NP_116205.3_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0000**.
# --------------------------------------------------------------------------------
# NP_116784.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# NP_203526.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.3235**.
# --------------------------------------------------------------------------------
# NP_852090.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# O00411.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0000**.
# --------------------------------------------------------------------------------
# O60220.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0935**.
# --------------------------------------------------------------------------------
# O75431.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
#
# Check errors.log for execution error details.
# --------------------------------------------------------------------------------
# O96008.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# P14406.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0479**.
# --------------------------------------------------------------------------------
# P20336.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0189**.
# --------------------------------------------------------------------------------
# P42765.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# P48507.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# P49406.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.2201**.
# --------------------------------------------------------------------------------
# P52815.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0055**.
# --------------------------------------------------------------------------------
# P56181.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# P82663.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0276**.
# --------------------------------------------------------------------------------
# Q12887.3_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0380**.
# --------------------------------------------------------------------------------
# Q13084.4_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# Q13405.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# Q13794.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.1793**.
# --------------------------------------------------------------------------------
# Q15070.4_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.3668**.
# --------------------------------------------------------------------------------
# Q15388.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0722**.
# --------------------------------------------------------------------------------
# Q8IXM3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
#
# Check errors.log for execution error details.
# --------------------------------------------------------------------------------
# Q8TCC3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.3296**.
# --------------------------------------------------------------------------------
# Q96EL2.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0044**.
# --------------------------------------------------------------------------------
# Q96GC5.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
#
# Check errors.log for execution error details.
# --------------------------------------------------------------------------------
# Q99689.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4959**.
# --------------------------------------------------------------------------------
# Q9BQ48.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# Q9BYD1.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# model-averaged inference, or rerunning the alignment with data at that
# site masked to confirm robustness of the result.
# --------------------------------------------------------------------------------
# Q9NQ50.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4954**.
# --------------------------------------------------------------------------------
# Q9NZE8.3_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# Q9UH62.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
#
# Check errors.log for execution error details.
# --------------------------------------------------------------------------------
# Q9UQM7.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# Q9Y2Z2.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4629**.
# --------------------------------------------------------------------------------
# Q9Y5Z4.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.5000**.
# --------------------------------------------------------------------------------
# Q9Y6G3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0001**.
# --------------------------------------------------------------------------------
# XP_054208573.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.0000**.
# --------------------------------------------------------------------------------
# XP_054220447.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# ## Branch-site unrestricted statistical test of episodic diversification [BUSTED]
# Likelihood ratio test for episodic diversifying positive selection, **p =   0.4982**.
# --------------------------------------------------------------------------------

# %%
import os

# Define the directory containing your log files
log_dir = 'mitimpair_absrel_noen'

# Iterate over all files in the directory
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        with open(filepath, 'r') as file:
            start_printing = False
            for line in file:
                if '### Adaptive branch site random effects likelihood test' in line:
                    start_printing = True
                    print(filename)  # Print the filename
                    print(line.strip())  # Print the starting line
                    continue
                if start_printing:
                    print(line.rstrip())
            if not start_printing:
                print(f"{filename} does not contain the target section.")
            # Add a separator between files
            print('-' * 80)

# %%
import os
import re

# Define the directory containing your .log files
log_dir = 'mitimpair_bustede1'  # Update this if your directory name is different

# Output file to store the protein names
output_file = 'mitimpair_bustede1_noen_prots_nofdr.txt'

# Open the output file in write mode
with open(output_file, 'w') as out_f:

    # Iterate over all .log files in the directory
    for filename in os.listdir(log_dir):
        if filename.endswith('.log'):
            filepath = os.path.join(log_dir, filename)
            # Extract the protein name from the filename based on the rules
            # Split the filename by '_'
            parts = filename.split('_')
            if parts[0].startswith('NP') or parts[0].startswith('XP'):
                # If the protein name starts with 'NP' or 'XP', join the first two parts
                protein_name = '_'.join(parts[:2])
            else:
                # Otherwise, the protein name is the first part
                protein_name = parts[0]

            # Open and read the log file
            with open(filepath, 'r') as log_f:
                lines = log_f.readlines()
                for line in lines:
                    if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                        # Extract the p-value from this line
                        match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                        if match:
                            p_value_str = match.group(1)
                            try:
                                p_value = float(p_value_str)
                                if p_value < 0.05:
                                    # Write the protein name to the output file
                                    out_f.write(protein_name + '\n')
                                    print(f"{protein_name}: p-value {p_value} < 0.05, added to {output_file}")
                                else:
                                    print(f"{protein_name}: p-value {p_value} >= 0.05, not added")
                            except ValueError:
                                print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                        else:
                            print(f"{protein_name}: p-value not found in line: {line.strip()}")
                        # Break after processing the line
                        break
                else:
                    # If we didn't find the line with 'Likelihood ratio test...'
                    print(f"{protein_name}: 'Likelihood ratio test' line not found in {filename}")
# Out:
# EAW70196.1: p-value 0.4824 >= 0.05, not added
# NP_001177793.1: 'Likelihood ratio test' line not found in NP_001177793.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# NP_001179.1: p-value 0.3714 >= 0.05, not added
# NP_001184044.1: p-value 0.5 >= 0.05, not added
# NP_001186768.2: p-value 0.5 >= 0.05, not added
# NP_001274364.1: p-value 0.484 >= 0.05, not added
# NP_001275684.1: p-value 0.5 >= 0.05, not added
# NP_001278360.1: p-value 0.5 >= 0.05, not added
# NP_001289201.1: p-value 0.5 >= 0.05, not added
# NP_001308657.1: p-value 0.4973 >= 0.05, not added
# NP_001309749.1: p-value 0.304 >= 0.05, not added
# NP_001310513.1: 'Likelihood ratio test' line not found in NP_001310513.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# NP_001317309.1: 'Likelihood ratio test' line not found in NP_001317309.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# NP_001339859.1: p-value 0.3713 >= 0.05, not added
# NP_001341754.1: p-value 0.5 >= 0.05, not added
# NP_001352690.1: p-value 0.4975 >= 0.05, not added
# NP_001361015.1: p-value 0.5 >= 0.05, not added
# NP_001362219.1: p-value 0.5 >= 0.05, not added
# NP_001363732.1: p-value 0.5 >= 0.05, not added
# NP_001365933.1: 'Likelihood ratio test' line not found in NP_001365933.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# NP_001372664.1: p-value 0.036 < 0.05, added to mitimpair_bustede1_noen_prots_nofdr.txt
# NP_001387053.1: p-value 0.5 >= 0.05, not added
# NP_001397864.1: p-value 0.5 >= 0.05, not added
# NP_004322.1: p-value 0.0005 < 0.05, added to mitimpair_bustede1_noen_prots_nofdr.txt
# NP_004620.1: p-value 0.364 >= 0.05, not added
# NP_054765.1: p-value 0.0115 < 0.05, added to mitimpair_bustede1_noen_prots_nofdr.txt
# NP_056195.3: p-value 0.5 >= 0.05, not added
# NP_057155.1: p-value 0.5 >= 0.05, not added
# NP_061764.2: p-value 0.5 >= 0.05, not added
# NP_115682.1: p-value 0.5 >= 0.05, not added
# NP_116205.3: p-value 0.5 >= 0.05, not added
# NP_116784.1: p-value 0.5 >= 0.05, not added
# NP_203526.1: p-value 0.0106 < 0.05, added to mitimpair_bustede1_noen_prots_nofdr.txt
# NP_852090.1: p-value 0.2366 >= 0.05, not added
# O00411.2: p-value 0.5 >= 0.05, not added
# O60220.1: p-value 0.5 >= 0.05, not added
# O75431.1: 'Likelihood ratio test' line not found in O75431.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# O96008.1: p-value 0.5 >= 0.05, not added
# P14406.1: p-value 0.1097 >= 0.05, not added
# P20336.1: p-value 0.5 >= 0.05, not added
# P42765.2: p-value 0.0549 >= 0.05, not added
# P48507.1: p-value 0.5 >= 0.05, not added
# P49406.2: p-value 0.0718 >= 0.05, not added
# P52815.2: p-value 0.0001 < 0.05, added to mitimpair_bustede1_noen_prots_nofdr.txt
# P56181.2: p-value 0.1611 >= 0.05, not added
# P82663.1: p-value 0.1378 >= 0.05, not added
# Q12887.3: p-value 0.5 >= 0.05, not added
# Q13084.4: p-value 0.5 >= 0.05, not added
# Q13405.1: p-value 0.5 >= 0.05, not added
# Q13794.1: p-value 0.5 >= 0.05, not added
# Q15070.4: p-value 0.3852 >= 0.05, not added
# Q15388.1: p-value 0.5 >= 0.05, not added
# Q8IXM3.1: 'Likelihood ratio test' line not found in Q8IXM3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# Q8TCC3.1: p-value 0.0545 >= 0.05, not added
# Q96EL2.1: p-value 0.4515 >= 0.05, not added
# Q96GC5.2: 'Likelihood ratio test' line not found in Q96GC5.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# Q99689.1: p-value 0.5 >= 0.05, not added
# Q9BQ48.1: p-value 0.5 >= 0.05, not added
# Q9BYD1.1: p-value 0.5 >= 0.05, not added
# Q9NQ50.1: p-value 0.5 >= 0.05, not added
# Q9NZE8.3: p-value 0.5 >= 0.05, not added
# Q9UH62.1: 'Likelihood ratio test' line not found in Q9UH62.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# Q9UQM7.2: p-value 0.4154 >= 0.05, not added
# Q9Y2Z2.2: p-value 0.5 >= 0.05, not added
# Q9Y5Z4.1: p-value 0.3634 >= 0.05, not added
# Q9Y6G3.1: p-value 0.5 >= 0.05, not added
# XP_054208573.1: p-value 0.5 >= 0.05, not added
# XP_054220447.1: p-value 0.4791 >= 0.05, not added

# %%
# %pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\anaconda\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\anaconda\lib\site-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\anaconda\lib\site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\anaconda\lib\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.8 MB 7.7 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.8 MB 8.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.8 MB 8.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.8 MB 8.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.8 MB 8.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.6/9.8 MB 1.9 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/9.8 MB 2.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.8 MB 2.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.5/9.8 MB 2.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/9.8 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 4.0 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'mitimpair_bustede1'

# Output file
output_file = 'mitimpair_bustede1_noen_prots.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# NP_001177793.1: 'Likelihood ratio test' line not found or no p-value in NP_001177793.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# NP_001310513.1: 'Likelihood ratio test' line not found or no p-value in NP_001310513.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# NP_001317309.1: 'Likelihood ratio test' line not found or no p-value in NP_001317309.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# NP_001365933.1: 'Likelihood ratio test' line not found or no p-value in NP_001365933.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# O75431.1: 'Likelihood ratio test' line not found or no p-value in O75431.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# Q8IXM3.1: 'Likelihood ratio test' line not found or no p-value in Q8IXM3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# Q96GC5.2: 'Likelihood ratio test' line not found or no p-value in Q96GC5.2_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# Q9UH62.1: 'Likelihood ratio test' line not found or no p-value in Q9UH62.1_bat_only_aligned_nucleotide_codon_aligned.fasta_busted.log
# EAW70196.1: raw p = 0.4824, FDR p = 0.5 (not significant)
# NP_001179.1: raw p = 0.3714, FDR p = 0.5 (not significant)
# NP_001184044.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001186768.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001274364.1: raw p = 0.484, FDR p = 0.5 (not significant)
# NP_001275684.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001278360.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001289201.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001308657.1: raw p = 0.4973, FDR p = 0.5 (not significant)
# NP_001309749.1: raw p = 0.304, FDR p = 0.5 (not significant)
# NP_001339859.1: raw p = 0.3713, FDR p = 0.5 (not significant)
# NP_001341754.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001352690.1: raw p = 0.4975, FDR p = 0.5 (not significant)
# NP_001361015.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001362219.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001363732.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001372664.1: raw p = 0.036, FDR p = 0.432 (not significant)
# NP_001387053.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001397864.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004322.1: raw p = 0.0005, FDR p = 0.015 (SIGNIFICANT)
# NP_004620.1: raw p = 0.364, FDR p = 0.5 (not significant)
# NP_054765.1: raw p = 0.0115, FDR p = 0.1725 (not significant)
# NP_056195.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_057155.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_061764.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_115682.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_116205.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_116784.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_203526.1: raw p = 0.0106, FDR p = 0.1725 (not significant)
# NP_852090.1: raw p = 0.2366, FDR p = 0.5 (not significant)
# O00411.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O60220.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O96008.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P14406.1: raw p = 0.1097, FDR p = 0.5 (not significant)
# P20336.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P42765.2: raw p = 0.0549, FDR p = 0.4706 (not significant)
# P48507.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P49406.2: raw p = 0.0718, FDR p = 0.5 (not significant)
# P52815.2: raw p = 0.0001, FDR p = 0.006 (SIGNIFICANT)
# P56181.2: raw p = 0.1611, FDR p = 0.5 (not significant)
# P82663.1: raw p = 0.1378, FDR p = 0.5 (not significant)
# Q12887.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13084.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13405.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13794.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15070.4: raw p = 0.3852, FDR p = 0.5 (not significant)
# Q15388.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8TCC3.1: raw p = 0.0545, FDR p = 0.4706 (not significant)
# Q96EL2.1: raw p = 0.4515, FDR p = 0.5 (not significant)
# Q99689.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BQ48.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BYD1.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9NQ50.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9NZE8.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UQM7.2: raw p = 0.4154, FDR p = 0.5 (not significant)
# Q9Y2Z2.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y5Z4.1: raw p = 0.3634, FDR p = 0.5 (not significant)
# Q9Y6G3.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_054208573.1: raw p = 0.5, FDR p = 0.5 (not significant)
# XP_054220447.1: raw p = 0.4791, FDR p = 0.5 (not significant)

# %%
import os

# Define the directory containing your log files
log_dir = 'mitimpair_absrel_noen'

# Define the path to the protein names file
protein_names_file = 'mitimpair_busted_noen_prots.txt'

# Read the protein names into a set for efficient lookup
with open(protein_names_file, 'r') as f:
    protein_names = set(line.strip() for line in f if line.strip())

# Iterate over all files in the directory
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        # Extract the protein name from the filename based on the rules
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            # If the protein name starts with 'NP' or 'XP', join the first two parts
            protein_name = '_'.join(parts[:2])
        else:
            # Otherwise, the protein name is the first part
            protein_name = parts[0]

        # Check if the protein name is in the set
        if protein_name in protein_names:
            filepath = os.path.join(log_dir, filename)
            with open(filepath, 'r') as file:
                start_printing = False
                for line in file:
                    if '### Adaptive branch site random effects likelihood test' in line:
                        start_printing = True
                        print(filename)  # Print the filename
                        print(line.strip())  # Print the starting line
                        continue
                    if start_printing:
                        print(line.rstrip())
                if not start_printing:
                    print(f"{filename} does not contain the target section.")
                # Add a separator between files
                print('-' * 80)
        else:
            # If the protein name is not in the list, skip the file
            continue
# Out:
# EAW70196.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **30** tested.
#
# * mlXP_006082442_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# NP_001179.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **26** tested.
#
# * pvXP_023394266_1, p-value =  0.00051
# --------------------------------------------------------------------------------
# NP_001361015.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **31** tested.
#
# * mlXP_006082826_2, p-value =  0.00000
# --------------------------------------------------------------------------------
# NP_001387053.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **31** tested.
#
# * mdXP_059515229_1, p-value =  0.00006
# --------------------------------------------------------------------------------
# NP_001397864.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **29** tested.
#
# * mbXP_014393896_1, p-value =  0.00196
# --------------------------------------------------------------------------------
# NP_004322.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **2** branches under selection among **27** tested.
#
# * mmXP_036168168_1, p-value =  0.00000
# * mbXP_014389106_1, p-value =  0.00002
# --------------------------------------------------------------------------------
# NP_004620.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **29** tested.
#
# * raXP_036094958_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# NP_054765.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **3** branches under selection among **30** tested.
#
# * mlXP_023600952_1, p-value =  0.00000
# * mdXP_059558158_1, p-value =  0.00000
# * sbXP_066109938_1, p-value =  0.00035
# --------------------------------------------------------------------------------
# NP_056195.3_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **2** branches under selection among **31** tested.
#
# * pvXP_023380608_1, p-value =  0.00000
# * Myobl, p-value =  0.00000
# --------------------------------------------------------------------------------
# NP_115682.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **29** tested.
#
# * Myobl, p-value =  0.00000
# --------------------------------------------------------------------------------
# NP_116205.3_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **3** branches under selection among **31** tested.
#
# * pvXP_023393423_1, p-value =  0.00000
# * mbXP_014392266_1, p-value =  0.00158
# * mmXP_036202425_1, p-value =  0.00846
# --------------------------------------------------------------------------------
# O00411.2_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **2** branches under selection among **31** tested.
#
# * pvXP_023376242_1, p-value =  0.00000
# * paXP_015455022_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# P14406.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **24** tested.
#
# * mlXP_023610053_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# P20336.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **27** tested.
#
# * phXP_045709307_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# P52815.2_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **2** branches under selection among **28** tested.
#
# * mlXP_006109297_1, p-value =  0.00000
# * pgXP_039715790_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# P82663.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **2** branches under selection among **26** tested.
#
# * Pteropusgv, p-value =  0.00000
# * raXP_015977530_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# Q12887.3_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **29** tested.
#
# * phXP_045680457_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# Q96EL2.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **1** branches under selection among **30** tested.
#
# * mbXP_005882988_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# Q9Y6G3.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **2** branches under selection among **27** tested.
#
# * pvXP_023387333_1, p-value =  0.00000
# * paXP_024896773_1, p-value =  0.00000
# --------------------------------------------------------------------------------
# XP_054208573.1_bat_only_aligned_nucleotide_codon_aligned.fasta_absrel.log
# ### Adaptive branch site random effects likelihood test
# Likelihood ratio test for episodic diversifying positive selection at Holm-Bonferroni corrected _p =   0.0500_ found **2** branches under selection among **29** tested.
#
# * mlXP_023604926_1, p-value =  0.00000
# * moXP_036136753_1, p-value =  0.00000
# --------------------------------------------------------------------------------
