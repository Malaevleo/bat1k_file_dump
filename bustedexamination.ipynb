# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'accumreactox_bustede'

# Output file
output_file = 'accumreactox_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# O15439.3: 'Likelihood ratio test' line not found or no p-value in O15439.3_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P18054.4: 'Likelihood ratio test' line not found or no p-value in P18054.4_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P52895.3: 'Likelihood ratio test' line not found or no p-value in P52895.3_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q12882.2: 'Likelihood ratio test' line not found or no p-value in Q12882.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q8WWV3.2: 'Likelihood ratio test' line not found or no p-value in Q8WWV3.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q9UBQ7.1: 'Likelihood ratio test' line not found or no p-value in Q9UBQ7.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# A5PLL7.3: raw p = 0.4425, FDR p = 0.5 (not significant)
# NP_000509.1: raw p = 0.4998, FDR p = 0.5 (not significant)
# NP_001193670.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001257377.1: raw p = 0.2873, FDR p = 0.5 (not significant)
# NP_001276681.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001358968.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005887.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_055050.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_060021.1: raw p = 0.0003, FDR p = 0.0096 (SIGNIFICANT)
# O00767.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O14756.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O15247.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O43181.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O43676.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O43708.3: raw p = 0.2911, FDR p = 0.5 (not significant)
# O43920.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O60427.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O75489.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O75592.4: raw p = 0.5, FDR p = 0.5 (not significant)
# O75911.2: raw p = 0.2996, FDR p = 0.5 (not significant)
# O75936.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O76003.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O95831.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O96000.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P00325.3: raw p = 0.1597, FDR p = 0.5 (not significant)
# P00387.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P00390.2: raw p = 0.4196, FDR p = 0.5 (not significant)
# P00441.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P00558.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P01127.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P04040.3: raw p = 0.4799, FDR p = 0.5 (not significant)
# P07101.5: raw p = 0.5, FDR p = 0.5 (not significant)
# P07327.2: raw p = 0.1653, FDR p = 0.5 (not significant)
# P07919.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P08294.2: raw p = 0.2025, FDR p = 0.5 (not significant)
# P08559.3: raw p = 0.316, FDR p = 0.5 (not significant)
# P08574.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P09211.2: raw p = 0.4902, FDR p = 0.5 (not significant)
# P10599.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P10620.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P11177.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P11509.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P11511.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P11586.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P13073.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P15428.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P21397.1: raw p = 0.4963, FDR p = 0.5 (not significant)
# P21912.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P30038.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P30041.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P30519.2: raw p = 0.0489, FDR p = 0.5 (not significant)
# P31930.3: raw p = 0.0022, FDR p = 0.0528 (not significant)
# P31937.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P32322.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P35520.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P35638.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P35754.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P40926.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P40939.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P47985.2: raw p = 0, FDR p = 0 (SIGNIFICANT)
# P48163.1: raw p = 0.4461, FDR p = 0.5 (not significant)
# P49189.3: raw p = 0.4938, FDR p = 0.5 (not significant)
# P50213.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P61457.2: raw p = 0.4861, FDR p = 0.5 (not significant)
# P69905.2: raw p = 0.2639, FDR p = 0.5 (not significant)
# P99999.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q00796.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q02252.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q06136.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q06830.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13423.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15067.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15526.1: raw p = 0.4992, FDR p = 0.5 (not significant)
# Q16134.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q16678.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q16698.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q16798.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q49A26.4: raw p = 0.2323, FDR p = 0.5 (not significant)
# Q8N118.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8N4Q1.1: raw p = 0.4959, FDR p = 0.5 (not significant)
# Q8WWM9.1: raw p = 0.1354, FDR p = 0.5 (not significant)
# Q8WWX9.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92781.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96IV6.1: raw p = 0.221, FDR p = 0.5 (not significant)
# Q96JB6.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99536.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99643.1: raw p = 0.1613, FDR p = 0.5 (not significant)
# Q9BQS7.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BY49.2: raw p = 0.0002, FDR p = 0.0096 (SIGNIFICANT)
# Q9H0N5.4: raw p = 0.1006, FDR p = 0.5 (not significant)
# Q9H3N1.1: raw p = 0.4974, FDR p = 0.5 (not significant)
# Q9NZC7.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UDR5.1: raw p = 0.2958, FDR p = 0.5 (not significant)
# Q9UJ68.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y3D2.2: raw p = 0.4259, FDR p = 0.5 (not significant)
# Q9Y6N1.3: raw p = 0.428, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'senaccum_bustede'

# Output file
output_file = 'senaccum_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# O15119.4: 'Likelihood ratio test' line not found or no p-value in O15119.4_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P06748.2: 'Likelihood ratio test' line not found or no p-value in P06748.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P45985.1: 'Likelihood ratio test' line not found or no p-value in P45985.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_001341661.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005421.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_055724.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O43324.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P01112.1: raw p = 0.4939, FDR p = 0.5 (not significant)
# P05121.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P08069.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P24941.2: raw p = 0.3828, FDR p = 0.5 (not significant)
# P37198.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P38936.3: raw p = 0.326, FDR p = 0.5 (not significant)
# P41182.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P42772.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P45983.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P45984.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q02363.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q05655.2: raw p = 0.4925, FDR p = 0.5 (not significant)
# Q99683.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H160.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H3D4.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9ULJ6.3: raw p = 0.0479, FDR p = 0.5 (not significant)
# Q9UM11.2: raw p = 0.5, FDR p = 0.5 (not significant)
# WEW62322.1: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'chromatinchange_bustede'

# Output file
output_file = 'ecmchange_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# NP_000543.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001835.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O00391.3: raw p = 0.2293, FDR p = 0.5 (not significant)
# O14672.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O15230.8: raw p = 0.5, FDR p = 0.5 (not significant)
# O60882.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O95967.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P01137.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P02461.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P05981.1: raw p = 0.2357, FDR p = 0.5 (not significant)
# P06396.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P08123.7: raw p = 0.4145, FDR p = 0.5 (not significant)
# P08253.2: raw p = 0.1724, FDR p = 0.5 (not significant)
# P08254.2: raw p = 0.4245, FDR p = 0.5 (not significant)
# P08493.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P08572.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P09237.1: raw p = 0.1823, FDR p = 0.5 (not significant)
# P09958.2: raw p = 0.4416, FDR p = 0.5 (not significant)
# P11047.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P14780.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P28300.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P29400.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P39900.1: raw p = 0.1203, FDR p = 0.5 (not significant)
# P45452.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P50281.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P53420.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P78325.2: raw p = 0.4031, FDR p = 0.5 (not significant)
# Q01955.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q04656.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q12805.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13751.1: raw p = 0.2388, FDR p = 0.5 (not significant)
# Q13753.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14766.4: raw p = 0.486, FDR p = 0.5 (not significant)
# Q16363.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9HCB6.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UBX5.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UNA0.2: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'telomere_bustede'

# Output file
output_file = 'telomere_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# P12004.1: 'Likelihood ratio test' line not found or no p-value in P12004.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P27694.2: 'Likelihood ratio test' line not found or no p-value in P27694.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P49959.3: 'Likelihood ratio test' line not found or no p-value in P49959.3_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P78527.3: 'Likelihood ratio test' line not found or no p-value in P78527.3_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q8IY18.2: 'Likelihood ratio test' line not found or no p-value in Q8IY18.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q9BQ83.1: 'Likelihood ratio test' line not found or no p-value in Q9BQ83.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P07992.1: raw p = 0.1606, FDR p = 0.5 (not significant)
# P12956.2: raw p = 0.3752, FDR p = 0.5 (not significant)
# P13010.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P18887.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P23497.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P25490.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P27695.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P35244.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q06609.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13535.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14191.2: raw p = 0.3868, FDR p = 0.5 (not significant)
# Q15554.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92889.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92900.2: raw p = 0.499, FDR p = 0.5 (not significant)
# Q96SD1.2: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'TOR_bustede'

# Output file
output_file = 'TOR_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# O60478.1: 'Likelihood ratio test' line not found or no p-value in O60478.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_061931.1: raw p = 0, FDR p = 0 (SIGNIFICANT)
# O00327.2: raw p = 0.4891, FDR p = 0.5 (not significant)
# O15379.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O43504.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P08F94.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P23443.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P31749.2: raw p = 0.4907, FDR p = 0.5 (not significant)
# P41159.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P42345.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P78509.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q03113.4: raw p = 0.4968, FDR p = 0.5 (not significant)
# Q13541.3: raw p = 0.0895, FDR p = 0.5 (not significant)
# Q6R327.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8N122.1: raw p = 0.462, FDR p = 0.5 (not significant)
# Q96A49.1: raw p = 0.4504, FDR p = 0.5 (not significant)
# Q96B36.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BPZ7.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9NQL2.1: raw p = 0.0008, FDR p = 0.0084 (SIGNIFICANT)
# Q9Y2Q5.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y4R8.2: raw p = 0.5, FDR p = 0.5 (not significant)
# XLE35970.1: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'nucarc_bustede'

# Output file
output_file = 'nucarc_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# P48739.2: 'Likelihood ratio test' line not found or no p-value in P48739.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P52948.4: 'Likelihood ratio test' line not found or no p-value in P52948.4_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_001185486.1: raw p = 0.4973, FDR p = 0.5 (not significant)
# NP_001265138.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O00499.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O94901.4: raw p = 0.0419, FDR p = 0.5 (not significant)
# P02545.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P05771.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P17252.4: raw p = 0.2806, FDR p = 0.5 (not significant)
# P26583.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P29590.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P43034.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P52594.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q12912.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14693.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14980.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q5JVS0.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8NC51.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92692.1: raw p = 0.0521, FDR p = 0.5 (not significant)
# Q9BTX1.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9GZM8.1: raw p = 0.4083, FDR p = 0.5 (not significant)
# Q9NQC3.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y4C1.4: raw p = 0.5, FDR p = 0.5 (not significant)

# %% [markdown]
# без fdr:
# O94901.4: raw p = 0.0419

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'mitdna_bustede'

# Output file
output_file = 'mitdna_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# P23921.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q12888: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y243.1: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'transcr_bustede'

# Output file
output_file = 'transcr_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# P52739.2: 'Likelihood ratio test' line not found or no p-value in P52739.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q06546.1: 'Likelihood ratio test' line not found or no p-value in Q06546.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q99592.1: 'Likelihood ratio test' line not found or no p-value in Q99592.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q9H422.1: 'Likelihood ratio test' line not found or no p-value in Q9H422.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# A8K855.1: raw p = 0.5, FDR p = 0.5 (not significant)
# A8K8V0.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001138774.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001289889.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001358355.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001373664.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001955.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004307.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O00257.3: raw p = 0.0437, FDR p = 0.5 (not significant)
# O00472.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O00744.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O14641.1: raw p = 0.3425, FDR p = 0.5 (not significant)
# O14776.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O15455.1: raw p = 0.4838, FDR p = 0.5 (not significant)
# O15525.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O43296.1: raw p = 0.4998, FDR p = 0.5 (not significant)
# O43298.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O43439.1: raw p = 0.3785, FDR p = 0.5 (not significant)
# O43623.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O43719.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O60248.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O60315.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O60519.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O75360.2: raw p = 0.4591, FDR p = 0.5 (not significant)
# O94900.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O95096.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O95760.1: raw p = 0.2485, FDR p = 0.5 (not significant)
# P05067.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P05230.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P05412.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P07947.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P08237.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P09017.2: raw p = 0.0461, FDR p = 0.5 (not significant)
# P09525.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P09629.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P10243.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P10747.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P11161.3: raw p = 0.3783, FDR p = 0.5 (not significant)
# P12757.2: raw p = 0.2933, FDR p = 0.5 (not significant)
# P14652.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P15036.1: raw p = 0.3768, FDR p = 0.5 (not significant)
# P15408.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P15692.3: raw p = 0.0003, FDR p = 0.0168 (SIGNIFICANT)
# P16333.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P17023.4: raw p = 0.0253, FDR p = 0.5 (not significant)
# P17026.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P17041.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P19793.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P19883.2: raw p = 0.027, FDR p = 0.5 (not significant)
# P20226.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P21453.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P22392.1: raw p = 0.4648, FDR p = 0.5 (not significant)
# P22670.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P22736.1: raw p = 0.495, FDR p = 0.5 (not significant)
# P24278.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P24468.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P25874.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P27037.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P28069.1: raw p = 0.4999, FDR p = 0.5 (not significant)
# P35712.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P35869.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P37275.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P42685.1: raw p = 0.1703, FDR p = 0.5 (not significant)
# P48443.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P48552.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P49023.3: raw p = 0, FDR p = 0 (SIGNIFICANT)
# P49116.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P50539.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P51946.1: raw p = 0.3415, FDR p = 0.5 (not significant)
# P53999.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P55290.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P57682.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P61586.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P61956.3: raw p = 0.065, FDR p = 0.5 (not significant)
# P61978.1: raw p = 0.0746, FDR p = 0.5 (not significant)
# P63098.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P63104.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P63241.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P84022.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q00653.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q00839.6: raw p = 0.5, FDR p = 0.5 (not significant)
# Q01094.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q01543.1: raw p = 0.0021, FDR p = 0.0882 (not significant)
# Q01844.1: raw p = 0.1287, FDR p = 0.5 (not significant)
# Q03135.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q04760.4: raw p = 0.4021, FDR p = 0.5 (not significant)
# Q05195.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q05481.2: raw p = 0.422, FDR p = 0.5 (not significant)
# Q07021.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q07666.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q08999.3: raw p = 0.4675, FDR p = 0.5 (not significant)
# Q12948.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13422.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13516.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13526.1: raw p = 0.4349, FDR p = 0.5 (not significant)
# Q13573.1: raw p = 0.3947, FDR p = 0.5 (not significant)
# Q13761.2: raw p = 0.0378, FDR p = 0.5 (not significant)
# Q13886.1: raw p = 0.4965, FDR p = 0.5 (not significant)
# Q14186.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14188.2: raw p = 0.1574, FDR p = 0.5 (not significant)
# Q14494.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14526.5: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14541.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14684.3: raw p = 0.4778, FDR p = 0.5 (not significant)
# Q14995.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15583.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15596.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15714.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15723.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15796.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15847.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q16254.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q16533.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q2KHR2.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q2M1K9.1: raw p = 0.0327, FDR p = 0.5 (not significant)
# Q32MZ4.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q3B8N5.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q6DJT9.1: raw p = 0.3142, FDR p = 0.5 (not significant)
# Q6H8Q1.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q6UUV7.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q86WI3.3: raw p = 0.457, FDR p = 0.5 (not significant)
# Q8N988.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92570.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92576.3: raw p = 0.4935, FDR p = 0.5 (not significant)
# Q92841.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96BR9.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96GC6.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96HQ0.2: raw p = 0.2936, FDR p = 0.5 (not significant)
# Q96I24.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96S94.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99576.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99612.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99732.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BTC0.5: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BUG6.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BYV9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9C0J9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9C0K0.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H165.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H3M7.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H609.1: raw p = 0.0646, FDR p = 0.5 (not significant)
# Q9H8G1.3: raw p = 0.1537, FDR p = 0.5 (not significant)
# Q9HAP2.2: raw p = 0.4971, FDR p = 0.5 (not significant)
# Q9HBE1.1: raw p = 0.274, FDR p = 0.5 (not significant)
# Q9HCS4.1: raw p = 0.341, FDR p = 0.5 (not significant)
# Q9NS37.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9NTW7.3: raw p = 0.4463, FDR p = 0.5 (not significant)
# Q9NZI7.1: raw p = 0.4804, FDR p = 0.5 (not significant)
# Q9UBK9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UFF9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UH73.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UJG1.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UJL9.2: raw p = 0.1933, FDR p = 0.5 (not significant)
# Q9UK53.2: raw p = 0.4987, FDR p = 0.5 (not significant)
# Q9UKM9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UKV8.3: raw p = 0.2503, FDR p = 0.5 (not significant)
# Q9ULX9.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UM47.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UM63.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UN79.3: raw p = 0, FDR p = 0 (SIGNIFICANT)
# Q9UPW0.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y2D9.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y2Y9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y5R5.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y5V3.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y613.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y618.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y6Y1.4: raw p = 0.5, FDR p = 0.5 (not significant)

# %% [markdown]
# без fdr:
# P09017.2: raw p = 0.0461
# P17023.4: raw p = 0.0253
# P19883.2: raw p = 0.027
# Q01543.1: raw p = 0.0021
# Q2M1K9.1: raw p = 0.0327

# %% [markdown]
# **chromatin remodel
# INS
# nucdna
# alt in hist**

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'nucdna_bustede'

# Output file
output_file = 'nucdna_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# O95243.1: 'Likelihood ratio test' line not found or no p-value in O95243.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P23025.1: 'Likelihood ratio test' line not found or no p-value in P23025.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P36639.4: 'Likelihood ratio test' line not found or no p-value in P36639.4_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P49642.1: 'Likelihood ratio test' line not found or no p-value in P49642.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q9NTJ3.2: 'Likelihood ratio test' line not found or no p-value in Q9NTJ3.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_001131026.1: raw p = 0.2618, FDR p = 0.5 (not significant)
# O00141.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O00571.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O43264.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O43543.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O43823.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O60216.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O60566.3: raw p = 0.4996, FDR p = 0.5 (not significant)
# O60729.1: raw p = 0.4805, FDR p = 0.5 (not significant)
# O95071.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O95985.1: raw p = 0.4296, FDR p = 0.5 (not significant)
# O95997.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P24385.1: raw p = 0.4021, FDR p = 0.5 (not significant)
# P24522.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P28340.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P28715.3: raw p = 0.4038, FDR p = 0.5 (not significant)
# P30153.4: raw p = 0.2623, FDR p = 0.5 (not significant)
# P33991.5: raw p = 0.5, FDR p = 0.5 (not significant)
# P33993.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P40692.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P43246.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P43681.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P45973.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P50613.1: raw p = 0.4746, FDR p = 0.5 (not significant)
# P62826.3: raw p = 0.2575, FDR p = 0.5 (not significant)
# P78406.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P78560.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q02880.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q08050.3: raw p = 0.3899, FDR p = 0.5 (not significant)
# Q12888.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13283.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14676.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q29RF7.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q3B726.1: raw p = 0.0008, FDR p = 0.0432 (SIGNIFICANT)
# Q5BN46.1: raw p = 0.4249, FDR p = 0.5 (not significant)
# Q8N3U4.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8N9N2.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8WVM7.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92630.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92985.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99459.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BQ15.1: raw p = 0.3466, FDR p = 0.5 (not significant)
# Q9BU64.1: raw p = 0.3614, FDR p = 0.5 (not significant)
# Q9BXS6.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9GZM3.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H8T0.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9HA38.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9HCK5.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9NX46.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UHC1.3: raw p = 0.4888, FDR p = 0.5 (not significant)
# Q9UNA4.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UNS1.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UPY3.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UQ84.2: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'INS_bustede'

# Output file
output_file = 'INS_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# NP_005535.1: 'Likelihood ratio test' line not found or no p-value in NP_005535.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# O00443.2: 'Likelihood ratio test' line not found or no p-value in O00443.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P23229.5: 'Likelihood ratio test' line not found or no p-value in P23229.5_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P29353.4: 'Likelihood ratio test' line not found or no p-value in P29353.4_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P43490.1: 'Likelihood ratio test' line not found or no p-value in P43490.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P98164.3: 'Likelihood ratio test' line not found or no p-value in P98164.3_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q92572.1: 'Likelihood ratio test' line not found or no p-value in Q92572.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_000589.2: raw p = 0.0241, FDR p = 0.233 (not significant)
# NP_001138471.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001400936.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O14508.1: raw p = 0.4608, FDR p = 0.5 (not significant)
# P01241.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P01286.1: raw p = 0.4028, FDR p = 0.5 (not significant)
# P06213.4: raw p = 0.0409, FDR p = 0.2965 (not significant)
# P10912.1: raw p = 0.4162, FDR p = 0.5 (not significant)
# P14735.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P18065.2: raw p = 0.0101, FDR p = 0.1464 (not significant)
# P22003.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P22692.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P24593.1: raw p = 0.1203, FDR p = 0.5 (not significant)
# P25054.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P27361.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P27986.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P28482.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P29279.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P49841.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P51636.2: raw p = 0.2675, FDR p = 0.5 (not significant)
# Q02643.2: raw p = 0.4791, FDR p = 0.5 (not significant)
# Q07890.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q6ZMU5.2: raw p = 0.0003, FDR p = 0.0087 (SIGNIFICANT)
# Q92847.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96I82.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99801.2: raw p = 0.2678, FDR p = 0.5 (not significant)
# Q9NZV1.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UEF7.2: raw p = 0.3996, FDR p = 0.5 (not significant)
# Q9Y4H2.2: raw p = 0.1785, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'chromremodel_bustede'

# Output file
output_file = 'chromremodel_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# A6NHR9.2: 'Likelihood ratio test' line not found or no p-value in A6NHR9.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_004955.2: 'Likelihood ratio test' line not found or no p-value in NP_004955.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P07910.4: 'Likelihood ratio test' line not found or no p-value in P07910.4_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q92769.2: 'Likelihood ratio test' line not found or no p-value in Q92769.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# O15054.4: raw p = 0.5, FDR p = 0.5 (not significant)
# O95863.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P06400.2: raw p = 0.2928, FDR p = 0.5 (not significant)
# P11387.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P25440.2: raw p = 0.4989, FDR p = 0.5 (not significant)
# P42898.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P51532.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P55209.1: raw p = 0.4037, FDR p = 0.5 (not significant)
# P62805.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P84243.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q01826.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q06587.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q09028.3: raw p = 0.4778, FDR p = 0.5 (not significant)
# Q09472.2: raw p = 0.4973, FDR p = 0.5 (not significant)
# Q13153.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8WUU5.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92522.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92688.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92785.2: raw p = 0.2517, FDR p = 0.5 (not significant)
# Q969G3.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96L91.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BUQ8.3: raw p = 0.4971, FDR p = 0.5 (not significant)
# Q9NRA0.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9NRC8.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UEE9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UGL1.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9ULW6.1: raw p = 0.3964, FDR p = 0.5 (not significant)
# Q9UQL6.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y294.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y2K1.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y6J9.1: raw p = 0.0012, FDR p = 0.0372 (SIGNIFICANT)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'histalt_bustede'

# Output file
output_file = 'histalt_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# O43318.1: 'Likelihood ratio test' line not found or no p-value in O43318.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P23246.2: 'Likelihood ratio test' line not found or no p-value in P23246.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q13620.4: 'Likelihood ratio test' line not found or no p-value in Q13620.4_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_001309133.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_056153.2: raw p = 0.4765, FDR p = 0.5 (not significant)
# NP_085150.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O00213.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O15516.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O60341.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O60907.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O75582.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O95696.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P15336.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P25208.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P63146.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13952.3: raw p = 0.4883, FDR p = 0.5 (not significant)
# Q15014.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15542.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q16594.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q7LBC6.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8N344.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92793.3: raw p = 0.2397, FDR p = 0.5 (not significant)
# Q96ST3.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BPY8.1: raw p = 0.3787, FDR p = 0.5 (not significant)
# Q9BQA1.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BV86.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BVI0.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9GZS3.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H2F5.1: raw p = 0.2826, FDR p = 0.5 (not significant)
# Q9P0U4.2: raw p = 0.4988, FDR p = 0.5 (not significant)
# Q9P2K3.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UI30.1: raw p = 0.0455, FDR p = 0.5 (not significant)
# Q9UJU2.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UKV0.2: raw p = 0.2006, FDR p = 0.5 (not significant)
# Q9Y2K7.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y6Q9.1: raw p = 0.3227, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'intercom_busted'

# Output file
output_file = 'intercom_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# O95399.1: 'Likelihood ratio test' line not found or no p-value in O95399.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P01210.1: 'Likelihood ratio test' line not found or no p-value in P01210.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P09651.5: 'Likelihood ratio test' line not found or no p-value in P09651.5_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P13473.2: 'Likelihood ratio test' line not found or no p-value in P13473.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q12959.2: 'Likelihood ratio test' line not found or no p-value in Q12959.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q9UPR0.2: 'Likelihood ratio test' line not found or no p-value in Q9UPR0.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_001186256.3: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001422887.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_002515.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_689867.1: raw p = 0.286, FDR p = 0.5 (not significant)
# O14649.1: raw p = 0.0001, FDR p = 0.0031 (SIGNIFICANT)
# O14908.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O43614.2: raw p = 0.3444, FDR p = 0.5 (not significant)
# O60333.5: raw p = 0.5, FDR p = 0.5 (not significant)
# O60664.3: raw p = 0.0363, FDR p = 0.3854 (not significant)
# O60880.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O60939.1: raw p = 0.4859, FDR p = 0.5 (not significant)
# O75791.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O76070.2: raw p = 0.2906, FDR p = 0.5 (not significant)
# O95715.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O95990.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P01019.4: raw p = 0.1416, FDR p = 0.5 (not significant)
# P02649.1: raw p = 0.2581, FDR p = 0.5 (not significant)
# P02708.3: raw p = 0.3468, FDR p = 0.5 (not significant)
# P02745.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P04216.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P05129.3: raw p = 0.0195, FDR p = 0.2591 (not significant)
# P07332.3: raw p = 0.0014, FDR p = 0.03255 (SIGNIFICANT)
# P08949.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P09038.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P09529.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P09544.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P11234.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P13727.2: raw p = 0.1508, FDR p = 0.5 (not significant)
# P14866.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P15328.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P17302.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P20382.3: raw p = 0.0113, FDR p = 0.1752 (not significant)
# P21554.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P21964.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P25445.1: raw p = 0.0038, FDR p = 0.07068 (not significant)
# P28222.1: raw p = 0.2303, FDR p = 0.5 (not significant)
# P28223.2: raw p = 0, FDR p = 0 (SIGNIFICANT)
# P32297.4: raw p = 0.135, FDR p = 0.5 (not significant)
# P32745.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P32971.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P35348.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P35368.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P35558.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P36544.5: raw p = 0.1005, FDR p = 0.5 (not significant)
# P41221.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P42857.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P43354.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P49238.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P51812.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P55011.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P55851.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P56705.4: raw p = 0.207, FDR p = 0.5 (not significant)
# P60568.1: raw p = 0.3782, FDR p = 0.5 (not significant)
# P61278.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P61328.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q01484.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q01650.2: raw p = 0.0373, FDR p = 0.3854 (not significant)
# Q02487.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q02641.3: raw p = 0, FDR p = 0 (SIGNIFICANT)
# Q06889.1: raw p = 0.371, FDR p = 0.5 (not significant)
# Q07869.2: raw p = 0.3237, FDR p = 0.5 (not significant)
# Q08289.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13641.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13887.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13936.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15111.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15853.1: raw p = 0.329, FDR p = 0.5 (not significant)
# Q16478.2: raw p = 0.4336, FDR p = 0.5 (not significant)
# Q16515.1: raw p = 0.4789, FDR p = 0.5 (not significant)
# Q16619.1: raw p = 0.4999, FDR p = 0.5 (not significant)
# Q16643.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q59H18.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q86VR8.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8NDV7.2: raw p = 0.3515, FDR p = 0.5 (not significant)
# Q92616.7: raw p = 0.3686, FDR p = 0.5 (not significant)
# Q92731.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92777.4: raw p = 0.115, FDR p = 0.5 (not significant)
# Q92913.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q93097.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96B97.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96HF1.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96RD6.2: raw p = 0.4984, FDR p = 0.5 (not significant)
# Q96RP7.1: raw p = 0.3343, FDR p = 0.5 (not significant)
# Q99988.3: raw p = 0.4975, FDR p = 0.5 (not significant)
# Q99996.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9GZV9.1: raw p = 0.4058, FDR p = 0.5 (not significant)
# Q9NR77.3: raw p = 0.4966, FDR p = 0.5 (not significant)
# Q9NRY4.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9NSA1.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UHW9.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UJA9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y6E0.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y6F9.2: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'ampk_busted'

# Output file
output_file = 'ampk_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# O75844.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P07550.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P10644.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P13861.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P22694.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P31323.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P54619.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q12802.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q15848.1: raw p = 0.4683, FDR p = 0.5 (not significant)
# Q96EB6.2: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'stem_busted'

# Output file
output_file = 'stem_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# NP_976028.2: 'Likelihood ratio test' line not found or no p-value in NP_976028.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P35222.1: 'Likelihood ratio test' line not found or no p-value in P35222.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_001269030.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001365403.1: raw p = 0.2997, FDR p = 0.5 (not significant)
# NP_001371922.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001399735.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004616.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O14905.3: raw p = 0.37, FDR p = 0.5 (not significant)
# O43474.3: raw p = 0.4598, FDR p = 0.5 (not significant)
# O43524.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O75084.2: raw p = 0.4559, FDR p = 0.5 (not significant)
# P01023.3: raw p = 0.4794, FDR p = 0.5 (not significant)
# P03372.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P10415.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P12821.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P18074.1: raw p = 0, FDR p = 0 (SIGNIFICANT)
# P21802.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P47974.3: raw p = 0, FDR p = 0 (SIGNIFICANT)
# P48431.1: raw p = 0.4554, FDR p = 0.5 (not significant)
# P56704.2: raw p = 0, FDR p = 0 (SIGNIFICANT)
# Q01860.1: raw p = 0.4861, FDR p = 0.5 (not significant)
# Q02297.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q06945.1: raw p = 0, FDR p = 0 (SIGNIFICANT)
# Q13253.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13485.1: raw p = 0.0088, FDR p = 0.04253 (SIGNIFICANT)
# Q6KC79.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8N474.1: raw p = 0.0005, FDR p = 0.0029 (SIGNIFICANT)
# Q92765.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9GZT5.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H204.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UQE7.2: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'degrprot_busted'

# Output file
output_file = 'degrprot_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# O94782.1: 'Likelihood ratio test' line not found or no p-value in O94782.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P09871.1: 'Likelihood ratio test' line not found or no p-value in P09871.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P17655.6: 'Likelihood ratio test' line not found or no p-value in P17655.6_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P29144.4: 'Likelihood ratio test' line not found or no p-value in P29144.4_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P54578.3: 'Likelihood ratio test' line not found or no p-value in P54578.3_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q04609.1: 'Likelihood ratio test' line not found or no p-value in Q04609.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q4J6C6.1: 'Likelihood ratio test' line not found or no p-value in Q4J6C6.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q92643.2: 'Likelihood ratio test' line not found or no p-value in Q92643.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q9BUN8.1: 'Likelihood ratio test' line not found or no p-value in Q9BUN8.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q9HBA9.1: 'Likelihood ratio test' line not found or no p-value in Q9HBA9.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q9NS56.1: 'Likelihood ratio test' line not found or no p-value in Q9NS56.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# A4D1P6.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001018064.1: raw p = 0.2753, FDR p = 0.5 (not significant)
# NP_001269732.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001273696.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001336114.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001362411.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001369649.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001375231.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_001701.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_004172.2: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_005993.1: raw p = 0.4664, FDR p = 0.5 (not significant)
# NP_068370.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O00237.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O14907.2: raw p = 0.4309, FDR p = 0.5 (not significant)
# O15519.1: raw p = 0.478, FDR p = 0.5 (not significant)
# O43765.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O75808.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O76024.2: raw p = 0.4912, FDR p = 0.5 (not significant)
# O94952.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P00749.3: raw p = 0.3495, FDR p = 0.5 (not significant)
# P06681.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P07949.3: raw p = 0.4393, FDR p = 0.5 (not significant)
# P08519.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P08603.4: raw p = 0.3237, FDR p = 0.5 (not significant)
# P10619.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P19440.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P22695.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P28070.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P29466.1: raw p = 0.4473, FDR p = 0.5 (not significant)
# P38159.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P42575.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P46934.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P48729.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P51512.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P54725.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P61077.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P62256.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P62333.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P62837.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P83111.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q00987.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q01804.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q12879.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13042.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13216.1: raw p = 0.0585, FDR p = 0.5 (not significant)
# Q13219.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13362.3: raw p = 0.2952, FDR p = 0.5 (not significant)
# Q13867.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q14669.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q16763.2: raw p = 0, FDR p = 0 (SIGNIFICANT)
# Q5GLZ8.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q5VYK3.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q5XPI4.1: raw p = 0.0654, FDR p = 0.5 (not significant)
# Q7L5N1.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q7Z7L7.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q86V97.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8IUQ4.2: raw p = 0.3408, FDR p = 0.5 (not significant)
# Q8N6M9.2: raw p = 0, FDR p = 0 (SIGNIFICANT)
# Q8NEZ5.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8NG06.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q8NHZ8.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92624.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92743.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92851.3: raw p = 0.0494, FDR p = 0.5 (not significant)
# Q92905.4: raw p = 0.3624, FDR p = 0.5 (not significant)
# Q96FX8.1: raw p = 0.4486, FDR p = 0.5 (not significant)
# Q99797.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99829.1: raw p = 0.4629, FDR p = 0.5 (not significant)
# Q99942.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9BT67.1: raw p = 0.0005, FDR p = 0.0105 (SIGNIFICANT)
# Q9H040.2: raw p = 0.4774, FDR p = 0.5 (not significant)
# Q9H306.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9H4A9.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9HB40.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UIQ6.3: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UKB1.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9ULZ9.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UNE7.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y252.1: raw p = 0.1323, FDR p = 0.5 (not significant)
# Q9Y297.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y508.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y5K6.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y5Z0.1: raw p = 0.5, FDR p = 0.5 (not significant)
# WHV00477.1: raw p = 0, FDR p = 0 (SIGNIFICANT)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'altmethyl_busted'

# Output file
output_file = 'altmethyl_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# Q13129.2: 'Likelihood ratio test' line not found or no p-value in Q13129.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# O15297.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O60264.1: raw p = 0.5, FDR p = 0.5 (not significant)
# O94776.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P01100.1: raw p = 0.3754, FDR p = 0.5 (not significant)
# P01106.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P35226.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P42336.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P46100.6: raw p = 0.5, FDR p = 0.5 (not significant)
# P49840.2: raw p = 0.4991, FDR p = 0.5 (not significant)
# Q15910.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q5T5X7.1: raw p = 0.2406, FDR p = 0.5 (not significant)
# Q99549.2: raw p = 0.4925, FDR p = 0.5 (not significant)
# Q9H9B1.4: raw p = 0, FDR p = 0 (SIGNIFICANT)
# Q9NRZ9.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9UIF9.4: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'impfold_busted'

# Output file
output_file = 'impfold_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# NP_004125.3: 'Likelihood ratio test' line not found or no p-value in NP_004125.3_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P14625.1: 'Likelihood ratio test' line not found or no p-value in P14625.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# P48723.1: 'Likelihood ratio test' line not found or no p-value in P48723.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# Q0VDF9.1: 'Likelihood ratio test' line not found or no p-value in Q0VDF9.1_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# O43516.3: raw p = 0.5, FDR p = 0.5 (not significant)
# O76031.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P07900.5: raw p = 0.5, FDR p = 0.5 (not significant)
# P08238.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P10809.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P10909.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P50502.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P50542.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P54652.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P62942.2: raw p = 0.5, FDR p = 0.5 (not significant)
# P68400.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q99615.2: raw p = 0.5, FDR p = 0.5 (not significant)

# %%
#!/usr/bin/env python3

import os
import re
from statsmodels.stats.multitest import multipletests

# Directory containing your .log files
log_dir = 'dismacro_busted'

# Output file
output_file = 'dismacro_bustede1_FDR.txt'

# We will store all (protein_name, p_value) in a list for later correction
pvals_data = []

# 1. Parse each .log file and extract p-values
for filename in os.listdir(log_dir):
    if filename.endswith('.log'):
        filepath = os.path.join(log_dir, filename)
        # Extract the protein name from the filename
        parts = filename.split('_')
        if parts[0].startswith('NP') or parts[0].startswith('XP'):
            protein_name = '_'.join(parts[:2])
        else:
            protein_name = parts[0]

        # Read the log file
        with open(filepath, 'r') as log_f:
            lines = log_f.readlines()
            found_pval = False
            for line in lines:
                if 'Likelihood ratio test for episodic diversifying positive selection' in line:
                    # Extract the p-value
                    match = re.search(r'p =\s*([\d\.eE+-]+)', line)
                    if match:
                        p_value_str = match.group(1)
                        try:
                            p_value = float(p_value_str)
                            # Store this (protein, p-value)
                            pvals_data.append((protein_name, p_value))
                            found_pval = True
                        except ValueError:
                            print(f"{protein_name}: Could not convert p-value '{p_value_str}' to float")
                    else:
                        print(f"{protein_name}: p-value not found in line: {line.strip()}")
                    break  # Stop after finding the line
            if not found_pval:
                print(f"{protein_name}: 'Likelihood ratio test' line not found or no p-value in {filename}")

# 2. Once we've collected all p-values, apply FDR correction
p_values = [x[1] for x in pvals_data]  # just the numeric p-values

if len(p_values) == 0:
    print("No p-values found. Exiting.")
    exit()

# Benjamini-Hochberg procedure (FDR)
# returns: reject (boolean array), pvals_corrected, alphacSidak, alphacBonf
reject_array, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')

# 3. Write results to file (only those that pass FDR, i.e., q < 0.05)
with open(output_file, 'w') as out_f:
    for i, (protein_name, original_pval) in enumerate(pvals_data):
        fdr_pval = pvals_corrected[i]
        if reject_array[i]:
            # This means fdr_pval < 0.05
            out_f.write(protein_name + '\n')
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (SIGNIFICANT)")
        else:
            print(f"{protein_name}: raw p = {original_pval:.4g}, FDR p = {fdr_pval:.4g} (not significant)")
# Out:
# Q9UKA2.2: 'Likelihood ratio test' line not found or no p-value in Q9UKA2.2_nucleotide.fasta_aligned_codon_alignment.fasta_busted.log
# NP_001307809.1: raw p = 0.5, FDR p = 0.5 (not significant)
# NP_057658.2: raw p = 0.5, FDR p = 0.5 (not significant)
# O15294.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P05109.1: raw p = 0.1215, FDR p = 0.5 (not significant)
# P06702.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P09429.3: raw p = 0.5, FDR p = 0.5 (not significant)
# P16615.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P42338.1: raw p = 0.3682, FDR p = 0.5 (not significant)
# P49768.1: raw p = 0.5, FDR p = 0.5 (not significant)
# P55061.2: raw p = 0.4861, FDR p = 0.5 (not significant)
# P55072.4: raw p = 0.5, FDR p = 0.5 (not significant)
# P62820.3: raw p = 0.4502, FDR p = 0.5 (not significant)
# Q12778.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q12983.4: raw p = 0.5, FDR p = 0.5 (not significant)
# Q13501.1: raw p = 0.281, FDR p = 0.5 (not significant)
# Q14457.2: raw p = 0.4936, FDR p = 0.5 (not significant)
# Q15751.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q6VVB1.2: raw p = 0.1888, FDR p = 0.5 (not significant)
# Q8N5K1.1: raw p = 0.1595, FDR p = 0.5 (not significant)
# Q8NFA0.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q92995.2: raw p = 0.5, FDR p = 0.5 (not significant)
# Q96A56.1: raw p = 0.0463, FDR p = 0.5 (not significant)
# Q99497.2: raw p = 0.4093, FDR p = 0.5 (not significant)
# Q9BWH2.2: raw p = 0.2162, FDR p = 0.5 (not significant)
# Q9H082.1: raw p = 0.5, FDR p = 0.5 (not significant)
# Q9Y4P1.2: raw p = 0.4877, FDR p = 0.5 (not significant)
